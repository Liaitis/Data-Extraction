# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from textblob import TextBlob
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# {'URL_ID': 'bctech2011', 'URL': 'https://insights.blackcoffer.com/ml-and-ai-based-insurance-premium-model-to-predict-premium-to-be-charged-by-the-insurance-company/', 'POSITIVE_SCORE': 34, 'NEGATIVE_SCORE': 8, 'POLARITY_SCORE': 0.6190476043083905, 'SUBJECTIVITY_SCORE': 0.07155025541473552, 'AVG_SENTENCE_LENGTH': 587.0, 'PERCENTAGE_COMPLEX_WORDS': 51.618398637137986, 'FOG_INDEX': 255.4473594548552, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 587.0, 'COMPLEX_WORD_COUNT': 303, 'WORD_COUNT': 587, 'SYLLABLE_PER_WORD': 2.5928449744463373, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.630323679727428}
# {'URL_ID': 'bctech2012', 'URL': 'https://insights.blackcoffer.com/streamlined-integration-interactive-brokers-api-with-python-for-desktop-trading-application/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.021390374217163773, 'AVG_SENTENCE_LENGTH': 187.0, 'PERCENTAGE_COMPLEX_WORDS': 42.780748663101605, 'FOG_INDEX': 91.91229946524065, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 187.0, 'COMPLEX_WORD_COUNT': 80, 'WORD_COUNT': 187, 'SYLLABLE_PER_WORD': 2.3475935828877006, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.491978609625669}
# {'URL_ID': 'bctech2013', 'URL': 'https://insights.blackcoffer.com/efficient-data-integration-and-user-friendly-interface-development-navigating-challenges-in-web-application-deployment/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.02162162150474799, 'AVG_SENTENCE_LENGTH': 185.0, 'PERCENTAGE_COMPLEX_WORDS': 44.32432432432433, 'FOG_INDEX': 91.72972972972974, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 185.0, 'COMPLEX_WORD_COUNT': 82, 'WORD_COUNT': 185, 'SYLLABLE_PER_WORD': 2.3675675675675674, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.524324324324325}
# {'URL_ID': 'bctech2014', 'URL': 'https://insights.blackcoffer.com/effective-management-of-social-media-data-extraction-strategies-for-authentication-security-and-reliability/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.021390374217163773, 'AVG_SENTENCE_LENGTH': 187.0, 'PERCENTAGE_COMPLEX_WORDS': 43.85026737967914, 'FOG_INDEX': 92.34010695187166, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 187.0, 'COMPLEX_WORD_COUNT': 82, 'WORD_COUNT': 187, 'SYLLABLE_PER_WORD': 2.390374331550802, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.518716577540107}
# {'URL_ID': 'bctech2015', 'URL': 'https://insights.blackcoffer.com/streamlined-trading-operations-interface-for-metatrader-4-empowering-efficient-management-and-monitoring/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.02127659563150747, 'AVG_SENTENCE_LENGTH': 188.0, 'PERCENTAGE_COMPLEX_WORDS': 44.148936170212764, 'FOG_INDEX': 92.85957446808511, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 188.0, 'COMPLEX_WORD_COUNT': 83, 'WORD_COUNT': 188, 'SYLLABLE_PER_WORD': 2.372340425531915, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.537234042553192}
# {'URL_ID': 'bctech2016', 'URL': 'https://insights.blackcoffer.com/efficient-aws-infrastructure-setup-and-management-addressing-security-scalability-and-compliance/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.02173913031663516, 'AVG_SENTENCE_LENGTH': 184.0, 'PERCENTAGE_COMPLEX_WORDS': 44.02173913043478, 'FOG_INDEX': 91.20869565217392, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 184.0, 'COMPLEX_WORD_COUNT': 81, 'WORD_COUNT': 184, 'SYLLABLE_PER_WORD': 2.380434782608696, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.554347826086956}
# {'URL_ID': 'bctech2017', 'URL': 'https://insights.blackcoffer.com/streamlined-equity-waterfall-calculation-and-deal-management-system/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.02127659563150747, 'AVG_SENTENCE_LENGTH': 188.0, 'PERCENTAGE_COMPLEX_WORDS': 43.08510638297872, 'FOG_INDEX': 92.43404255319149, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 188.0, 'COMPLEX_WORD_COUNT': 81, 'WORD_COUNT': 188, 'SYLLABLE_PER_WORD': 2.345744680851064, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.4361702127659575}
# {'URL_ID': 'bctech2018', 'URL': 'https://insights.blackcoffer.com/automated-orthopedic-case-report-generation-harnessing-web-scraping-and-ai-integration/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.021390374217163773, 'AVG_SENTENCE_LENGTH': 187.0, 'PERCENTAGE_COMPLEX_WORDS': 44.38502673796791, 'FOG_INDEX': 92.55401069518717, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 187.0, 'COMPLEX_WORD_COUNT': 83, 'WORD_COUNT': 187, 'SYLLABLE_PER_WORD': 2.3636363636363638, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.481283422459893}
# {'URL_ID': 'bctech2019', 'URL': 'https://insights.blackcoffer.com/streamlining-time-calculation-in-warehouse-management-leveraging-shiphero-api-and-google-bigquery-integration/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.02040816316118284, 'AVG_SENTENCE_LENGTH': 196.0, 'PERCENTAGE_COMPLEX_WORDS': 43.87755102040816, 'FOG_INDEX': 95.95102040816327, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 196.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 196, 'SYLLABLE_PER_WORD': 2.372448979591837, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.469387755102041}
# {'URL_ID': 'bctech2020', 'URL': 'https://insights.blackcoffer.com/efficient-database-design-and-management-streamlining-access-and-integration-for-partner-entity-management/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.021390374217163773, 'AVG_SENTENCE_LENGTH': 187.0, 'PERCENTAGE_COMPLEX_WORDS': 44.38502673796791, 'FOG_INDEX': 92.55401069518717, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 187.0, 'COMPLEX_WORD_COUNT': 83, 'WORD_COUNT': 187, 'SYLLABLE_PER_WORD': 2.3850267379679146, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.540106951871658}
# {'URL_ID': 'bctech2021', 'URL': 'https://insights.blackcoffer.com/automated-campaign-management-system-a-comprehensive-solution-with-linkedin-and-email-integration/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.020942408267317233, 'AVG_SENTENCE_LENGTH': 191.0, 'PERCENTAGE_COMPLEX_WORDS': 44.50261780104712, 'FOG_INDEX': 94.20104712041885, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 191.0, 'COMPLEX_WORD_COUNT': 85, 'WORD_COUNT': 191, 'SYLLABLE_PER_WORD': 2.3821989528795813, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.513089005235602}
# {'URL_ID': 'bctech2022', 'URL': 'https://insights.blackcoffer.com/ai-driven-data-analysis-ai-tool-using-langchain-for-a-leading-real-estate-and-financing-firm-worldwide/', 'POSITIVE_SCORE': 19, 'NEGATIVE_SCORE': 4, 'POLARITY_SCORE': 0.6521738846880919, 'SUBJECTIVITY_SCORE': 0.047034764729990255, 'AVG_SENTENCE_LENGTH': 489.0, 'PERCENTAGE_COMPLEX_WORDS': 41.308793456032724, 'FOG_INDEX': 212.1235173824131, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 489.0, 'COMPLEX_WORD_COUNT': 202, 'WORD_COUNT': 489, 'SYLLABLE_PER_WORD': 2.3885480572597135, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.139059304703476}
# {'URL_ID': 'bctech2023', 'URL': 'https://insights.blackcoffer.com/grafana-dashboard-to-visualize-and-analyze-sensors-data/', 'POSITIVE_SCORE': 19, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.7272726942148775, 'SUBJECTIVITY_SCORE': 0.060606060439101765, 'AVG_SENTENCE_LENGTH': 363.0, 'PERCENTAGE_COMPLEX_WORDS': 44.90358126721763, 'FOG_INDEX': 163.16143250688708, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 363.0, 'COMPLEX_WORD_COUNT': 163, 'WORD_COUNT': 363, 'SYLLABLE_PER_WORD': 2.4077134986225897, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.203856749311295}
# {'URL_ID': 'bctech2024', 'URL': 'https://insights.blackcoffer.com/mvp-for-a-software-that-analyses-content-from-audio-pharma-based/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.39999996000000404, 'SUBJECTIVITY_SCORE': 0.037593984821075246, 'AVG_SENTENCE_LENGTH': 266.0, 'PERCENTAGE_COMPLEX_WORDS': 43.609022556390975, 'FOG_INDEX': 123.8436090225564, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 266.0, 'COMPLEX_WORD_COUNT': 116, 'WORD_COUNT': 266, 'SYLLABLE_PER_WORD': 2.3609022556390977, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.327067669172933}
# {'URL_ID': 'bctech2025', 'URL': 'https://insights.blackcoffer.com/data-engineering-and-management-tool-airbyte-with-custom-data-connectors-to-manage-crm-database/', 'POSITIVE_SCORE': 20, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.8181817809917372, 'SUBJECTIVITY_SCORE': 0.04856512130559576, 'AVG_SENTENCE_LENGTH': 453.0, 'PERCENTAGE_COMPLEX_WORDS': 48.12362030905077, 'FOG_INDEX': 200.4494481236203, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 453.0, 'COMPLEX_WORD_COUNT': 218, 'WORD_COUNT': 453, 'SYLLABLE_PER_WORD': 2.4944812362030904, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.2759381898454745}
# {'URL_ID': 'bctech2026', 'URL': 'https://insights.blackcoffer.com/text-summarizing-tool-to-scrape-and-summarize-pubmed-medical-papers/', 'POSITIVE_SCORE': 31, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.8235293875432533, 'SUBJECTIVITY_SCORE': 0.07925407906933782, 'AVG_SENTENCE_LENGTH': 429.0, 'PERCENTAGE_COMPLEX_WORDS': 43.58974358974359, 'FOG_INDEX': 189.03589743589745, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 429.0, 'COMPLEX_WORD_COUNT': 187, 'WORD_COUNT': 429, 'SYLLABLE_PER_WORD': 2.41025641025641, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.4125874125874125}
# {'URL_ID': 'bctech2027', 'URL': 'https://insights.blackcoffer.com/7up7down-10updown-snakes-and-ladder-games-built-using-oops/', 'POSITIVE_SCORE': 20, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.9047618616780065, 'SUBJECTIVITY_SCORE': 0.053030302896388125, 'AVG_SENTENCE_LENGTH': 396.0, 'PERCENTAGE_COMPLEX_WORDS': 45.45454545454545, 'FOG_INDEX': 176.5818181818182, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 396.0, 'COMPLEX_WORD_COUNT': 180, 'WORD_COUNT': 396, 'SYLLABLE_PER_WORD': 2.3914141414141414, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.25}
# {'URL_ID': 'bctech2028', 'URL': 'https://insights.blackcoffer.com/data-studio-dashboard-with-a-data-pipeline-tool-synced-with-podio-using-custom-webhooks-and-google-cloud-function/', 'POSITIVE_SCORE': 24, 'NEGATIVE_SCORE': 4, 'POLARITY_SCORE': 0.7142856887755111, 'SUBJECTIVITY_SCORE': 0.05702647646226787, 'AVG_SENTENCE_LENGTH': 491.0, 'PERCENTAGE_COMPLEX_WORDS': 41.955193482688394, 'FOG_INDEX': 213.18207739307536, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 491.0, 'COMPLEX_WORD_COUNT': 206, 'WORD_COUNT': 491, 'SYLLABLE_PER_WORD': 2.4114052953156824, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.256619144602851}
# {'URL_ID': 'bctech2029', 'URL': 'https://insights.blackcoffer.com/end-to-end-tool-to-optimize-routing-and-planning-of-field-engineers-using-googles-cvrp-tw-algorithm/', 'POSITIVE_SCORE': 32, 'NEGATIVE_SCORE': 7, 'POLARITY_SCORE': 0.6410256245890866, 'SUBJECTIVITY_SCORE': 0.09027777756880144, 'AVG_SENTENCE_LENGTH': 432.0, 'PERCENTAGE_COMPLEX_WORDS': 49.30555555555556, 'FOG_INDEX': 192.52222222222224, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 432.0, 'COMPLEX_WORD_COUNT': 213, 'WORD_COUNT': 432, 'SYLLABLE_PER_WORD': 2.525462962962963, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.506944444444445}
# {'URL_ID': 'bctech2030', 'URL': 'https://insights.blackcoffer.com/end-to-end-tool-to-predict-biofuel-prices-using-ieso-data/', 'POSITIVE_SCORE': 26, 'NEGATIVE_SCORE': 7, 'POLARITY_SCORE': 0.5757575583103771, 'SUBJECTIVITY_SCORE': 0.07096774178286507, 'AVG_SENTENCE_LENGTH': 465.0, 'PERCENTAGE_COMPLEX_WORDS': 41.935483870967744, 'FOG_INDEX': 202.7741935483871, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 465.0, 'COMPLEX_WORD_COUNT': 195, 'WORD_COUNT': 465, 'SYLLABLE_PER_WORD': 2.3806451612903228, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.193548387096774}
# {'URL_ID': 'bctech2031', 'URL': 'https://insights.blackcoffer.com/etl-discovery-tool-using-llma-langchain-openai/', 'POSITIVE_SCORE': 24, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.8461538136094686, 'SUBJECTIVITY_SCORE': 0.04896421836353255, 'AVG_SENTENCE_LENGTH': 531.0, 'PERCENTAGE_COMPLEX_WORDS': 40.11299435028249, 'FOG_INDEX': 228.44519774011303, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 531.0, 'COMPLEX_WORD_COUNT': 213, 'WORD_COUNT': 531, 'SYLLABLE_PER_WORD': 2.2598870056497176, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.062146892655368}
# {'URL_ID': 'bctech2032', 'URL': 'https://insights.blackcoffer.com/gpt-ocr-api/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.018656716348295833, 'AVG_SENTENCE_LENGTH': 268.0, 'PERCENTAGE_COMPLEX_WORDS': 41.417910447761194, 'FOG_INDEX': 123.76716417910448, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 268.0, 'COMPLEX_WORD_COUNT': 111, 'WORD_COUNT': 268, 'SYLLABLE_PER_WORD': 2.2388059701492535, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.985074626865671}
# {'URL_ID': 'bctech2033', 'URL': 'https://insights.blackcoffer.com/dockerize-the-aws-lambda-for-serverless-architecture/', 'POSITIVE_SCORE': 11, 'NEGATIVE_SCORE': 7, 'POLARITY_SCORE': 0.2222222098765439, 'SUBJECTIVITY_SCORE': 0.04699738891123397, 'AVG_SENTENCE_LENGTH': 383.0, 'PERCENTAGE_COMPLEX_WORDS': 49.60835509138381, 'FOG_INDEX': 173.04334203655355, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 383.0, 'COMPLEX_WORD_COUNT': 190, 'WORD_COUNT': 383, 'SYLLABLE_PER_WORD': 2.5613577023498695, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.68668407310705}
# {'URL_ID': 'bctech2034', 'URL': 'https://insights.blackcoffer.com/design-and-develop-a-product-recommendation-engine-based-on-the-features-of-products/', 'POSITIVE_SCORE': 20, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999999500000024, 'SUBJECTIVITY_SCORE': 0.06042296054252882, 'AVG_SENTENCE_LENGTH': 331.0, 'PERCENTAGE_COMPLEX_WORDS': 46.52567975830816, 'FOG_INDEX': 151.0102719033233, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 331.0, 'COMPLEX_WORD_COUNT': 154, 'WORD_COUNT': 331, 'SYLLABLE_PER_WORD': 2.4531722054380665, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.404833836858006}
# {'URL_ID': 'bctech2035', 'URL': 'https://insights.blackcoffer.com/database-discovery-tool-using-openai/', 'POSITIVE_SCORE': 15, 'NEGATIVE_SCORE': 5, 'POLARITY_SCORE': 0.4999999750000012, 'SUBJECTIVITY_SCORE': 0.05221932101248219, 'AVG_SENTENCE_LENGTH': 383.0, 'PERCENTAGE_COMPLEX_WORDS': 46.47519582245431, 'FOG_INDEX': 171.79007832898174, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 383.0, 'COMPLEX_WORD_COUNT': 178, 'WORD_COUNT': 383, 'SYLLABLE_PER_WORD': 2.4673629242819843, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.295039164490862}
# {'URL_ID': 'bctech2036', 'URL': 'https://insights.blackcoffer.com/automate-the-data-management-process/', 'POSITIVE_SCORE': 17, 'NEGATIVE_SCORE': 9, 'POLARITY_SCORE': 0.30769229585798863, 'SUBJECTIVITY_SCORE': 0.055319148818469895, 'AVG_SENTENCE_LENGTH': 470.0, 'PERCENTAGE_COMPLEX_WORDS': 43.61702127659575, 'FOG_INDEX': 205.44680851063833, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 470.0, 'COMPLEX_WORD_COUNT': 205, 'WORD_COUNT': 470, 'SYLLABLE_PER_WORD': 2.480851063829787, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.223404255319149}
# {'URL_ID': 'bctech2037', 'URL': 'https://insights.blackcoffer.com/realtime-kibana-dashboard-for-a-financial-tech-firm/', 'POSITIVE_SCORE': 20, 'NEGATIVE_SCORE': 14, 'POLARITY_SCORE': 0.17647058304498286, 'SUBJECTIVITY_SCORE': 0.05841924388587759, 'AVG_SENTENCE_LENGTH': 582.0, 'PERCENTAGE_COMPLEX_WORDS': 35.051546391752574, 'FOG_INDEX': 246.82061855670105, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 582.0, 'COMPLEX_WORD_COUNT': 204, 'WORD_COUNT': 582, 'SYLLABLE_PER_WORD': 2.2216494845360826, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.702749140893471}
# {'URL_ID': 'bctech2038', 'URL': 'https://insights.blackcoffer.com/data-management-etl-and-data-automation/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.024390243817455595, 'AVG_SENTENCE_LENGTH': 287.0, 'PERCENTAGE_COMPLEX_WORDS': 35.54006968641115, 'FOG_INDEX': 129.01602787456446, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 287.0, 'COMPLEX_WORD_COUNT': 102, 'WORD_COUNT': 287, 'SYLLABLE_PER_WORD': 2.163763066202091, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.923344947735192}
# {'URL_ID': 'bctech2039', 'URL': 'https://insights.blackcoffer.com/data-management-egeas/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.02745098028450596, 'AVG_SENTENCE_LENGTH': 255.0, 'PERCENTAGE_COMPLEX_WORDS': 35.294117647058826, 'FOG_INDEX': 116.11764705882354, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 255.0, 'COMPLEX_WORD_COUNT': 90, 'WORD_COUNT': 255, 'SYLLABLE_PER_WORD': 2.1098039215686275, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.113725490196078}
# {'URL_ID': 'bctech2040', 'URL': 'https://insights.blackcoffer.com/design-and-develop-powershell-script/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.02489626545686197, 'AVG_SENTENCE_LENGTH': 241.0, 'PERCENTAGE_COMPLEX_WORDS': 36.51452282157676, 'FOG_INDEX': 111.0058091286307, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 241.0, 'COMPLEX_WORD_COUNT': 88, 'WORD_COUNT': 241, 'SYLLABLE_PER_WORD': 2.224066390041494, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.045643153526971}
# {'URL_ID': 'bctech2041', 'URL': 'https://insights.blackcoffer.com/design-and-develop-jenkins-shared-library/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.03389830489322992, 'AVG_SENTENCE_LENGTH': 177.0, 'PERCENTAGE_COMPLEX_WORDS': 40.67796610169492, 'FOG_INDEX': 87.07118644067798, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 177.0, 'COMPLEX_WORD_COUNT': 72, 'WORD_COUNT': 177, 'SYLLABLE_PER_WORD': 2.3220338983050848, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.288135593220339}
# {'URL_ID': 'bctech2042', 'URL': 'https://insights.blackcoffer.com/design-and-develop-retool-app-for-wholecell-io-and-asana-data-using-their-apis/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.028037383046554284, 'AVG_SENTENCE_LENGTH': 214.0, 'PERCENTAGE_COMPLEX_WORDS': 35.51401869158878, 'FOG_INDEX': 99.80560747663552, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 214.0, 'COMPLEX_WORD_COUNT': 76, 'WORD_COUNT': 214, 'SYLLABLE_PER_WORD': 2.2383177570093458, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.9766355140186915}
# {'URL_ID': 'bctech2043', 'URL': 'https://insights.blackcoffer.com/design-and-develop-a-retool-app-that-will-show-stock-and-crypto-related-information-using-iex-api/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.025089605644840123, 'AVG_SENTENCE_LENGTH': 279.0, 'PERCENTAGE_COMPLEX_WORDS': 32.61648745519714, 'FOG_INDEX': 124.64659498207887, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 279.0, 'COMPLEX_WORD_COUNT': 91, 'WORD_COUNT': 279, 'SYLLABLE_PER_WORD': 2.082437275985663, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.530465949820789}
# {'URL_ID': 'bctech2044', 'URL': 'https://insights.blackcoffer.com/crm-monday-com-make-com-to-data-warehouse-to-klipfolio-dashboard/', 'POSITIVE_SCORE': 11, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.8333332638888947, 'SUBJECTIVITY_SCORE': 0.03183023864236011, 'AVG_SENTENCE_LENGTH': 377.0, 'PERCENTAGE_COMPLEX_WORDS': 32.891246684350136, 'FOG_INDEX': 163.95649867374004, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 377.0, 'COMPLEX_WORD_COUNT': 124, 'WORD_COUNT': 377, 'SYLLABLE_PER_WORD': 2.0689655172413794, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.941644562334218}
# {'URL_ID': 'bctech2045', 'URL': 'https://insights.blackcoffer.com/ner-task-using-bert-with-data-in-xml-format/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.02583025820726842, 'AVG_SENTENCE_LENGTH': 271.0, 'PERCENTAGE_COMPLEX_WORDS': 38.00738007380074, 'FOG_INDEX': 123.6029520295203, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 271.0, 'COMPLEX_WORD_COUNT': 103, 'WORD_COUNT': 271, 'SYLLABLE_PER_WORD': 2.2029520295202953, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.948339483394834}
# {'URL_ID': 'bctech2046', 'URL': 'https://insights.blackcoffer.com/qualtrics-api-integration-using-python/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.026086956408317583, 'AVG_SENTENCE_LENGTH': 230.0, 'PERCENTAGE_COMPLEX_WORDS': 37.391304347826086, 'FOG_INDEX': 106.95652173913044, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 230.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 230, 'SYLLABLE_PER_WORD': 2.256521739130435, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.1695652173913045}
# {'URL_ID': 'bctech2047', 'URL': 'https://insights.blackcoffer.com/design-and-develop-mlops-framework-for-data-centric-ai/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.7499999062500118, 'SUBJECTIVITY_SCORE': 0.029197080185412116, 'AVG_SENTENCE_LENGTH': 274.0, 'PERCENTAGE_COMPLEX_WORDS': 39.416058394160586, 'FOG_INDEX': 125.36642335766425, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 274.0, 'COMPLEX_WORD_COUNT': 108, 'WORD_COUNT': 274, 'SYLLABLE_PER_WORD': 2.281021897810219, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.1678832116788325}
# {'URL_ID': 'bctech2048', 'URL': 'https://insights.blackcoffer.com/nlp-based-approach-for-data-transformation/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.7499999062500118, 'SUBJECTIVITY_SCORE': 0.03319502060914929, 'AVG_SENTENCE_LENGTH': 241.0, 'PERCENTAGE_COMPLEX_WORDS': 36.51452282157676, 'FOG_INDEX': 111.0058091286307, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 241.0, 'COMPLEX_WORD_COUNT': 88, 'WORD_COUNT': 241, 'SYLLABLE_PER_WORD': 2.2448132780082988, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.979253112033195}
# {'URL_ID': 'bctech2049', 'URL': 'https://insights.blackcoffer.com/an-etl-tool-to-pull-data-from-shiphero-to-google-bigquery-data-warehouse/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.5384614970414233, 'SUBJECTIVITY_SCORE': 0.038123167043627074, 'AVG_SENTENCE_LENGTH': 341.0, 'PERCENTAGE_COMPLEX_WORDS': 38.41642228739003, 'FOG_INDEX': 151.76656891495603, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 341.0, 'COMPLEX_WORD_COUNT': 131, 'WORD_COUNT': 341, 'SYLLABLE_PER_WORD': 2.313782991202346, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.941348973607038}
# {'URL_ID': 'bctech2050', 'URL': 'https://insights.blackcoffer.com/plaid-financial-analytics-a-data-driven-dashboard-to-generate-insights/', 'POSITIVE_SCORE': 9, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.7999999200000081, 'SUBJECTIVITY_SCORE': 0.03663003649586067, 'AVG_SENTENCE_LENGTH': 273.0, 'PERCENTAGE_COMPLEX_WORDS': 39.56043956043956, 'FOG_INDEX': 125.02417582417584, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 273.0, 'COMPLEX_WORD_COUNT': 108, 'WORD_COUNT': 273, 'SYLLABLE_PER_WORD': 2.3443223443223444, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.131868131868132}
# {'URL_ID': 'bctech2051', 'URL': 'https://insights.blackcoffer.com/recommendation-engine-for-insurance-sector-to-expand-business-in-the-rural-area/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.8181817438016598, 'SUBJECTIVITY_SCORE': 0.034374999892578126, 'AVG_SENTENCE_LENGTH': 320.0, 'PERCENTAGE_COMPLEX_WORDS': 42.5, 'FOG_INDEX': 145.0, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 320.0, 'COMPLEX_WORD_COUNT': 136, 'WORD_COUNT': 320, 'SYLLABLE_PER_WORD': 2.396875, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.24375}
# {'URL_ID': 'bctech2052', 'URL': 'https://insights.blackcoffer.com/data-from-crm-via-zapier-to-google-sheets-dynamic-to-powerbi/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999990000001, 'SUBJECTIVITY_SCORE': 0.038759689772249264, 'AVG_SENTENCE_LENGTH': 258.0, 'PERCENTAGE_COMPLEX_WORDS': 32.945736434108525, 'FOG_INDEX': 116.37829457364342, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 258.0, 'COMPLEX_WORD_COUNT': 85, 'WORD_COUNT': 258, 'SYLLABLE_PER_WORD': 2.1744186046511627, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.887596899224806}
# {'URL_ID': 'bctech2053', 'URL': 'https://insights.blackcoffer.com/data-warehouse-to-google-data-studio-looker-dashboard/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.02447552438994572, 'AVG_SENTENCE_LENGTH': 286.0, 'PERCENTAGE_COMPLEX_WORDS': 34.61538461538461, 'FOG_INDEX': 128.24615384615387, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 286.0, 'COMPLEX_WORD_COUNT': 99, 'WORD_COUNT': 286, 'SYLLABLE_PER_WORD': 2.2132867132867133, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.006993006993007}
# {'URL_ID': 'bctech2054', 'URL': 'https://insights.blackcoffer.com/crm-monday-com-via-zapier-to-power-bi-dashboard/', 'POSITIVE_SCORE': 14, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.6470587854671302, 'SUBJECTIVITY_SCORE': 0.055921052447628114, 'AVG_SENTENCE_LENGTH': 304.0, 'PERCENTAGE_COMPLEX_WORDS': 29.93421052631579, 'FOG_INDEX': 133.57368421052632, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 304.0, 'COMPLEX_WORD_COUNT': 91, 'WORD_COUNT': 304, 'SYLLABLE_PER_WORD': 2.0526315789473686, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.707236842105263}
# {'URL_ID': 'bctech2055', 'URL': 'https://insights.blackcoffer.com/monday-com-to-kpi-dashboard-to-manage-view-and-generate-insights-from-the-crm-data/', 'POSITIVE_SCORE': 18, 'NEGATIVE_SCORE': 6, 'POLARITY_SCORE': 0.4999999791666675, 'SUBJECTIVITY_SCORE': 0.07476635490726992, 'AVG_SENTENCE_LENGTH': 321.0, 'PERCENTAGE_COMPLEX_WORDS': 35.202492211838006, 'FOG_INDEX': 142.48099688473522, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 321.0, 'COMPLEX_WORD_COUNT': 113, 'WORD_COUNT': 321, 'SYLLABLE_PER_WORD': 2.102803738317757, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.735202492211838}
# {'URL_ID': 'bctech2056', 'URL': 'https://insights.blackcoffer.com/data-management-for-a-political-saas-application/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.33333329629630043, 'SUBJECTIVITY_SCORE': 0.02623906697889485, 'AVG_SENTENCE_LENGTH': 343.0, 'PERCENTAGE_COMPLEX_WORDS': 39.067055393586, 'FOG_INDEX': 152.8268221574344, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 343.0, 'COMPLEX_WORD_COUNT': 134, 'WORD_COUNT': 343, 'SYLLABLE_PER_WORD': 2.253644314868805, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.982507288629738}
# {'URL_ID': 'bctech2057', 'URL': 'https://insights.blackcoffer.com/google-lsa-ads-google-local-service-ads-etl-tools-and-dashboards/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.021660649741297295, 'AVG_SENTENCE_LENGTH': 277.0, 'PERCENTAGE_COMPLEX_WORDS': 36.101083032490976, 'FOG_INDEX': 125.2404332129964, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 277.0, 'COMPLEX_WORD_COUNT': 100, 'WORD_COUNT': 277, 'SYLLABLE_PER_WORD': 2.2021660649819497, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.963898916967509}
# {'URL_ID': 'bctech2058', 'URL': 'https://insights.blackcoffer.com/ad-networks-marketing-campaign-data-dashboard-in-looker-google-data-studio/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.029126213450843624, 'AVG_SENTENCE_LENGTH': 206.0, 'PERCENTAGE_COMPLEX_WORDS': 38.349514563106794, 'FOG_INDEX': 97.73980582524273, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 206.0, 'COMPLEX_WORD_COUNT': 79, 'WORD_COUNT': 206, 'SYLLABLE_PER_WORD': 2.266990291262136, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.194174757281553}
# {'URL_ID': 'bctech2059', 'URL': 'https://insights.blackcoffer.com/analytical-solution-for-a-tech-firm/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.5555554938271674, 'SUBJECTIVITY_SCORE': 0.0473684208033241, 'AVG_SENTENCE_LENGTH': 190.0, 'PERCENTAGE_COMPLEX_WORDS': 40.526315789473685, 'FOG_INDEX': 92.21052631578948, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 190.0, 'COMPLEX_WORD_COUNT': 77, 'WORD_COUNT': 190, 'SYLLABLE_PER_WORD': 2.3105263157894735, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.331578947368421}
# {'URL_ID': 'bctech2060', 'URL': 'https://insights.blackcoffer.com/ai-solution-for-a-technology-information-and-internet-firm/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.028985507106350207, 'AVG_SENTENCE_LENGTH': 207.0, 'PERCENTAGE_COMPLEX_WORDS': 40.09661835748793, 'FOG_INDEX': 98.83864734299517, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 207.0, 'COMPLEX_WORD_COUNT': 83, 'WORD_COUNT': 207, 'SYLLABLE_PER_WORD': 2.289855072463768, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.1980676328502415}
# {'URL_ID': 'bctech2061', 'URL': 'https://insights.blackcoffer.com/ai-and-nlp-based-solutions-to-automate-data-discovery-for-venture-capital-and-private-equity-principals/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.026615969480547643, 'AVG_SENTENCE_LENGTH': 263.0, 'PERCENTAGE_COMPLEX_WORDS': 44.866920152091254, 'FOG_INDEX': 123.14676806083651, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 263.0, 'COMPLEX_WORD_COUNT': 118, 'WORD_COUNT': 263, 'SYLLABLE_PER_WORD': 2.365019011406844, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.266159695817491}
# {'URL_ID': 'bctech2062', 'URL': 'https://insights.blackcoffer.com/an-etl-solution-for-an-internet-publishing-firm/', 'POSITIVE_SCORE': 12, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999999166666736, 'SUBJECTIVITY_SCORE': 0.039603960265333464, 'AVG_SENTENCE_LENGTH': 303.0, 'PERCENTAGE_COMPLEX_WORDS': 34.65346534653465, 'FOG_INDEX': 135.06138613861387, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 303.0, 'COMPLEX_WORD_COUNT': 105, 'WORD_COUNT': 303, 'SYLLABLE_PER_WORD': 2.221122112211221, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.702970297029703}
# {'URL_ID': 'bctech2063', 'URL': 'https://insights.blackcoffer.com/ai-based-algorithmic-trading-bot-for-forex/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.02857142843537415, 'AVG_SENTENCE_LENGTH': 210.0, 'PERCENTAGE_COMPLEX_WORDS': 37.61904761904762, 'FOG_INDEX': 99.04761904761905, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 210.0, 'COMPLEX_WORD_COUNT': 79, 'WORD_COUNT': 210, 'SYLLABLE_PER_WORD': 2.2714285714285714, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.171428571428572}
# {'URL_ID': 'bctech2064', 'URL': 'https://insights.blackcoffer.com/equity-waterfalls-model-based-saas-application-for-real-estate-sector/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.33333329629630043, 'SUBJECTIVITY_SCORE': 0.028938906659360428, 'AVG_SENTENCE_LENGTH': 311.0, 'PERCENTAGE_COMPLEX_WORDS': 41.157556270096464, 'FOG_INDEX': 140.8630225080386, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 311.0, 'COMPLEX_WORD_COUNT': 128, 'WORD_COUNT': 311, 'SYLLABLE_PER_WORD': 2.302250803858521, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.048231511254019}
# {'URL_ID': 'bctech2065', 'URL': 'https://insights.blackcoffer.com/ai-solutions-for-foreign-exchange-an-automated-algo-trading-tool/', 'POSITIVE_SCORE': 8, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.7777776913580343, 'SUBJECTIVITY_SCORE': 0.025787965542154827, 'AVG_SENTENCE_LENGTH': 349.0, 'PERCENTAGE_COMPLEX_WORDS': 39.82808022922636, 'FOG_INDEX': 155.53123209169055, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 349.0, 'COMPLEX_WORD_COUNT': 139, 'WORD_COUNT': 349, 'SYLLABLE_PER_WORD': 2.2120343839541547, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.951289398280802}
# {'URL_ID': 'bctech2066', 'URL': 'https://insights.blackcoffer.com/ai-agent-development-and-deployment-in-jina-ai/', 'POSITIVE_SCORE': 11, 'NEGATIVE_SCORE': 6, 'POLARITY_SCORE': 0.2941176297577865, 'SUBJECTIVITY_SCORE': 0.06746031719261779, 'AVG_SENTENCE_LENGTH': 252.0, 'PERCENTAGE_COMPLEX_WORDS': 40.07936507936508, 'FOG_INDEX': 116.83174603174604, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 252.0, 'COMPLEX_WORD_COUNT': 101, 'WORD_COUNT': 252, 'SYLLABLE_PER_WORD': 2.3452380952380953, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.2103174603174605}
# {'URL_ID': 'bctech2067', 'URL': 'https://insights.blackcoffer.com/golden-record-a-knowledge-graph-database-approach-to-unfold-discovery-using-neo4j/', 'POSITIVE_SCORE': 13, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.6249999609375024, 'SUBJECTIVITY_SCORE': 0.04984423660484662, 'AVG_SENTENCE_LENGTH': 321.0, 'PERCENTAGE_COMPLEX_WORDS': 38.940809968847354, 'FOG_INDEX': 143.97632398753896, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 321.0, 'COMPLEX_WORD_COUNT': 125, 'WORD_COUNT': 321, 'SYLLABLE_PER_WORD': 2.3146417445482865, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.071651090342679}
# {'URL_ID': 'bctech2068', 'URL': 'https://insights.blackcoffer.com/advanced-ai-for-trading-automation/', 'POSITIVE_SCORE': 13, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.7333332844444478, 'SUBJECTIVITY_SCORE': 0.04518072275547975, 'AVG_SENTENCE_LENGTH': 332.0, 'PERCENTAGE_COMPLEX_WORDS': 40.06024096385542, 'FOG_INDEX': 148.8240963855422, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 332.0, 'COMPLEX_WORD_COUNT': 133, 'WORD_COUNT': 332, 'SYLLABLE_PER_WORD': 2.3373493975903616, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.969879518072289}
# {'URL_ID': 'bctech2069', 'URL': 'https://insights.blackcoffer.com/create-a-knowledge-graph-to-provide-real-time-analytics-recommendations-and-a-single-source-of-truth/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.33333329629630043, 'SUBJECTIVITY_SCORE': 0.039130434612476374, 'AVG_SENTENCE_LENGTH': 230.0, 'PERCENTAGE_COMPLEX_WORDS': 43.04347826086957, 'FOG_INDEX': 109.21739130434783, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 230.0, 'COMPLEX_WORD_COUNT': 99, 'WORD_COUNT': 230, 'SYLLABLE_PER_WORD': 2.3521739130434782, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.260869565217392}
# {'URL_ID': 'bctech2070', 'URL': 'https://insights.blackcoffer.com/advanced-ai-for-thermal-person-detection/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.031088082740476256, 'AVG_SENTENCE_LENGTH': 193.0, 'PERCENTAGE_COMPLEX_WORDS': 39.37823834196891, 'FOG_INDEX': 92.95129533678757, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 193.0, 'COMPLEX_WORD_COUNT': 76, 'WORD_COUNT': 193, 'SYLLABLE_PER_WORD': 2.321243523316062, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.227979274611399}
# {'URL_ID': 'bctech2071', 'URL': 'https://insights.blackcoffer.com/advanced-ai-for-road-cam-threat-detection/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.4999999375000079, 'SUBJECTIVITY_SCORE': 0.03940886680094154, 'AVG_SENTENCE_LENGTH': 203.0, 'PERCENTAGE_COMPLEX_WORDS': 41.87192118226601, 'FOG_INDEX': 97.94876847290641, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 203.0, 'COMPLEX_WORD_COUNT': 85, 'WORD_COUNT': 203, 'SYLLABLE_PER_WORD': 2.3596059113300494, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.295566502463054}
# {'URL_ID': 'bctech2072', 'URL': 'https://insights.blackcoffer.com/advanced-ai-for-pedestrian-crossing-safety/', 'POSITIVE_SCORE': 8, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.599999940000006, 'SUBJECTIVITY_SCORE': 0.04807692284578403, 'AVG_SENTENCE_LENGTH': 208.0, 'PERCENTAGE_COMPLEX_WORDS': 41.82692307692308, 'FOG_INDEX': 99.93076923076924, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 208.0, 'COMPLEX_WORD_COUNT': 87, 'WORD_COUNT': 208, 'SYLLABLE_PER_WORD': 2.360576923076923, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.360576923076923}
# {'URL_ID': 'bctech2073', 'URL': 'https://insights.blackcoffer.com/handgun-detection-using-yolo/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.034825870473503134, 'AVG_SENTENCE_LENGTH': 201.0, 'PERCENTAGE_COMPLEX_WORDS': 43.28358208955223, 'FOG_INDEX': 97.7134328358209, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 201.0, 'COMPLEX_WORD_COUNT': 87, 'WORD_COUNT': 201, 'SYLLABLE_PER_WORD': 2.388059701492537, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.343283582089552}
# {'URL_ID': 'bctech2074', 'URL': 'https://insights.blackcoffer.com/using-graph-technology-to-create-single-customer-view/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 5, 'POLARITY_SCORE': 0.16666665277777895, 'SUBJECTIVITY_SCORE': 0.05128205106289722, 'AVG_SENTENCE_LENGTH': 234.0, 'PERCENTAGE_COMPLEX_WORDS': 41.88034188034188, 'FOG_INDEX': 110.35213675213674, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 234.0, 'COMPLEX_WORD_COUNT': 98, 'WORD_COUNT': 234, 'SYLLABLE_PER_WORD': 2.3803418803418803, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.311965811965812}
# {'URL_ID': 'bctech2075', 'URL': 'https://insights.blackcoffer.com/car-detection-in-satellite-images/', 'POSITIVE_SCORE': 14, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999999285714337, 'SUBJECTIVITY_SCORE': 0.046666666511111114, 'AVG_SENTENCE_LENGTH': 300.0, 'PERCENTAGE_COMPLEX_WORDS': 38.666666666666664, 'FOG_INDEX': 135.46666666666667, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 300.0, 'COMPLEX_WORD_COUNT': 116, 'WORD_COUNT': 300, 'SYLLABLE_PER_WORD': 2.32, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.026666666666666}
# {'URL_ID': 'bctech2076', 'URL': 'https://insights.blackcoffer.com/building-a-physics-informed-neural-network-for-circuit-evaluation/', 'POSITIVE_SCORE': 11, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.5714285306122479, 'SUBJECTIVITY_SCORE': 0.04320987640984606, 'AVG_SENTENCE_LENGTH': 324.0, 'PERCENTAGE_COMPLEX_WORDS': 41.66666666666667, 'FOG_INDEX': 146.26666666666668, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 324.0, 'COMPLEX_WORD_COUNT': 135, 'WORD_COUNT': 324, 'SYLLABLE_PER_WORD': 2.330246913580247, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.37037037037037}
# {'URL_ID': 'bctech2077', 'URL': 'https://insights.blackcoffer.com/connecting-mongodb-database-to-power-bi-dashboard-dashboard-automation/', 'POSITIVE_SCORE': 8, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.4545454132231443, 'SUBJECTIVITY_SCORE': 0.03160919531146783, 'AVG_SENTENCE_LENGTH': 348.0, 'PERCENTAGE_COMPLEX_WORDS': 38.2183908045977, 'FOG_INDEX': 154.4873563218391, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 348.0, 'COMPLEX_WORD_COUNT': 133, 'WORD_COUNT': 348, 'SYLLABLE_PER_WORD': 2.2758620689655173, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.818965517241379}
# {'URL_ID': 'bctech2078', 'URL': 'https://insights.blackcoffer.com/data-transformation/', 'POSITIVE_SCORE': 17, 'NEGATIVE_SCORE': 12, 'POLARITY_SCORE': 0.17241378715814526, 'SUBJECTIVITY_SCORE': 0.07591623016775856, 'AVG_SENTENCE_LENGTH': 382.0, 'PERCENTAGE_COMPLEX_WORDS': 37.95811518324607, 'FOG_INDEX': 167.98324607329846, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 382.0, 'COMPLEX_WORD_COUNT': 145, 'WORD_COUNT': 382, 'SYLLABLE_PER_WORD': 2.225130890052356, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.7539267015706805}
# {'URL_ID': 'bctech2079', 'URL': 'https://insights.blackcoffer.com/e-commerce-store-analysis-purchase-behavior-ad-spend-conversion-traffic-etc/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.8181817438016598, 'SUBJECTIVITY_SCORE': 0.03273809514066043, 'AVG_SENTENCE_LENGTH': 336.0, 'PERCENTAGE_COMPLEX_WORDS': 40.17857142857143, 'FOG_INDEX': 150.4714285714286, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 336.0, 'COMPLEX_WORD_COUNT': 135, 'WORD_COUNT': 336, 'SYLLABLE_PER_WORD': 2.324404761904762, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.0476190476190474}
# {'URL_ID': 'bctech2080', 'URL': 'https://insights.blackcoffer.com/kpi-dashboard-for-accountants/', 'POSITIVE_SCORE': 12, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999999166666736, 'SUBJECTIVITY_SCORE': 0.038709677294484914, 'AVG_SENTENCE_LENGTH': 310.0, 'PERCENTAGE_COMPLEX_WORDS': 36.774193548387096, 'FOG_INDEX': 138.70967741935485, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 310.0, 'COMPLEX_WORD_COUNT': 114, 'WORD_COUNT': 310, 'SYLLABLE_PER_WORD': 2.235483870967742, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.109677419354838}
# {'URL_ID': 'bctech2081', 'URL': 'https://insights.blackcoffer.com/return-on-advertising-spend-dashboard-marketing-automation-and-analytics-using-etl-and-dashboard/', 'POSITIVE_SCORE': 27, 'NEGATIVE_SCORE': 4, 'POLARITY_SCORE': 0.7419354599375658, 'SUBJECTIVITY_SCORE': 0.05438596481686673, 'AVG_SENTENCE_LENGTH': 570.0, 'PERCENTAGE_COMPLEX_WORDS': 44.73684210526316, 'FOG_INDEX': 245.89473684210526, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 570.0, 'COMPLEX_WORD_COUNT': 255, 'WORD_COUNT': 570, 'SYLLABLE_PER_WORD': 2.354385964912281, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.2403508771929825}
# {'URL_ID': 'bctech2082', 'URL': 'https://insights.blackcoffer.com/ranking-customer-behaviours-for-business-strategy/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.4999999375000079, 'SUBJECTIVITY_SCORE': 0.030651340878730494, 'AVG_SENTENCE_LENGTH': 261.0, 'PERCENTAGE_COMPLEX_WORDS': 35.63218390804598, 'FOG_INDEX': 118.6528735632184, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 261.0, 'COMPLEX_WORD_COUNT': 93, 'WORD_COUNT': 261, 'SYLLABLE_PER_WORD': 2.264367816091954, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.0}
# {'URL_ID': 'bctech2083', 'URL': 'https://insights.blackcoffer.com/algorithmic-trading-for-multiple-commodities-markets-like-forex-metals-energy-etc/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.021943573598922968, 'AVG_SENTENCE_LENGTH': 319.0, 'PERCENTAGE_COMPLEX_WORDS': 40.75235109717868, 'FOG_INDEX': 143.9009404388715, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 319.0, 'COMPLEX_WORD_COUNT': 130, 'WORD_COUNT': 319, 'SYLLABLE_PER_WORD': 2.413793103448276, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.235109717868339}
# {'URL_ID': 'bctech2084', 'URL': 'https://insights.blackcoffer.com/trading-bot-for-forex/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.599999880000024, 'SUBJECTIVITY_SCORE': 0.02717391289579395, 'AVG_SENTENCE_LENGTH': 184.0, 'PERCENTAGE_COMPLEX_WORDS': 38.58695652173913, 'FOG_INDEX': 89.03478260869565, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 184.0, 'COMPLEX_WORD_COUNT': 71, 'WORD_COUNT': 184, 'SYLLABLE_PER_WORD': 2.3043478260869565, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.119565217391305}
# {'URL_ID': 'bctech2085', 'URL': 'https://insights.blackcoffer.com/python-model-for-the-analysis-of-sector-specific-stock-etfs-for-investment-purposes%ef%bf%bc/', 'POSITIVE_SCORE': 9, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.636363578512402, 'SUBJECTIVITY_SCORE': 0.037542661987909, 'AVG_SENTENCE_LENGTH': 293.0, 'PERCENTAGE_COMPLEX_WORDS': 37.20136518771331, 'FOG_INDEX': 132.08054607508532, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 293.0, 'COMPLEX_WORD_COUNT': 109, 'WORD_COUNT': 293, 'SYLLABLE_PER_WORD': 2.2866894197952217, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.088737201365188}
# {'URL_ID': 'bctech2086', 'URL': 'https://insights.blackcoffer.com/medical-classification/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.020689655101070153, 'AVG_SENTENCE_LENGTH': 290.0, 'PERCENTAGE_COMPLEX_WORDS': 37.58620689655172, 'FOG_INDEX': 131.0344827586207, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 290.0, 'COMPLEX_WORD_COUNT': 109, 'WORD_COUNT': 290, 'SYLLABLE_PER_WORD': 2.2758620689655173, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.024137931034483}
# {'URL_ID': 'bctech2087', 'URL': 'https://insights.blackcoffer.com/design-develop-bert-question-answering-model-explanations-with-visualization/', 'POSITIVE_SCORE': 3, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999996666667778, 'SUBJECTIVITY_SCORE': 0.01470588228085352, 'AVG_SENTENCE_LENGTH': 204.0, 'PERCENTAGE_COMPLEX_WORDS': 41.17647058823529, 'FOG_INDEX': 98.07058823529412, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 204.0, 'COMPLEX_WORD_COUNT': 84, 'WORD_COUNT': 204, 'SYLLABLE_PER_WORD': 2.3676470588235294, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.416666666666667}
# {'URL_ID': 'bctech2088', 'URL': 'https://insights.blackcoffer.com/design-and-develop-solution-to-anomaly-detection-classification-problems/', 'POSITIVE_SCORE': 3, 'NEGATIVE_SCORE': 7, 'POLARITY_SCORE': -0.39999996000000404, 'SUBJECTIVITY_SCORE': 0.04149377576143662, 'AVG_SENTENCE_LENGTH': 241.0, 'PERCENTAGE_COMPLEX_WORDS': 42.738589211618255, 'FOG_INDEX': 113.4954356846473, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 241.0, 'COMPLEX_WORD_COUNT': 103, 'WORD_COUNT': 241, 'SYLLABLE_PER_WORD': 2.3900414937759336, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.161825726141079}
# {'URL_ID': 'bctech2089', 'URL': 'https://insights.blackcoffer.com/an-etl-solution-for-currency-data-to-google-big-query/', 'POSITIVE_SCORE': 3, 'NEGATIVE_SCORE': 5, 'POLARITY_SCORE': -0.24999996875000394, 'SUBJECTIVITY_SCORE': 0.028880866321729724, 'AVG_SENTENCE_LENGTH': 277.0, 'PERCENTAGE_COMPLEX_WORDS': 33.2129963898917, 'FOG_INDEX': 124.0851985559567, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 277.0, 'COMPLEX_WORD_COUNT': 92, 'WORD_COUNT': 277, 'SYLLABLE_PER_WORD': 2.187725631768953, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.725631768953068}
# {'URL_ID': 'bctech2090', 'URL': 'https://insights.blackcoffer.com/etl-and-mlops-infrastructure-for-blockchain-analytics/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.013201320088444489, 'AVG_SENTENCE_LENGTH': 303.0, 'PERCENTAGE_COMPLEX_WORDS': 38.613861386138616, 'FOG_INDEX': 136.64554455445545, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 303.0, 'COMPLEX_WORD_COUNT': 117, 'WORD_COUNT': 303, 'SYLLABLE_PER_WORD': 2.201320132013201, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.003300330033003}
# {'URL_ID': 'bctech2091', 'URL': 'https://insights.blackcoffer.com/an-agent-based-model-of-a-virtual-power-plant-vpp/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.022471909986112867, 'AVG_SENTENCE_LENGTH': 178.0, 'PERCENTAGE_COMPLEX_WORDS': 38.764044943820224, 'FOG_INDEX': 86.7056179775281, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 178.0, 'COMPLEX_WORD_COUNT': 69, 'WORD_COUNT': 178, 'SYLLABLE_PER_WORD': 2.3258426966292136, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.213483146067416}
# {'URL_ID': 'bctech2092', 'URL': 'https://insights.blackcoffer.com/transform-api-into-sdk-library-and-widget/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999990000001, 'SUBJECTIVITY_SCORE': 0.042194092648970075, 'AVG_SENTENCE_LENGTH': 237.0, 'PERCENTAGE_COMPLEX_WORDS': 38.39662447257383, 'FOG_INDEX': 110.15864978902954, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 237.0, 'COMPLEX_WORD_COUNT': 91, 'WORD_COUNT': 237, 'SYLLABLE_PER_WORD': 2.2447257383966246, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.042194092827004}
# {'URL_ID': 'bctech2093', 'URL': 'https://insights.blackcoffer.com/integration-of-a-product-to-a-cloud-based-crm-platform/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 6, 'POLARITY_SCORE': 0.07692307100591762, 'SUBJECTIVITY_SCORE': 0.045774647726145604, 'AVG_SENTENCE_LENGTH': 284.0, 'PERCENTAGE_COMPLEX_WORDS': 38.732394366197184, 'FOG_INDEX': 129.09295774647887, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 284.0, 'COMPLEX_WORD_COUNT': 110, 'WORD_COUNT': 284, 'SYLLABLE_PER_WORD': 2.257042253521127, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.130281690140845}
# {'URL_ID': 'bctech2094', 'URL': 'https://insights.blackcoffer.com/a-web-based-dashboard-for-the-filtered-data-retrieval-of-land-records/', 'POSITIVE_SCORE': 12, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.5999999600000027, 'SUBJECTIVITY_SCORE': 0.04731861183811163, 'AVG_SENTENCE_LENGTH': 317.0, 'PERCENTAGE_COMPLEX_WORDS': 35.33123028391167, 'FOG_INDEX': 140.93249211356468, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 317.0, 'COMPLEX_WORD_COUNT': 112, 'WORD_COUNT': 317, 'SYLLABLE_PER_WORD': 2.2397476340694005, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.022082018927445}
# {'URL_ID': 'bctech2095', 'URL': 'https://insights.blackcoffer.com/integration-of-video-conferencing-data-to-the-existing-web-app/', 'POSITIVE_SCORE': 3, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999996666667778, 'SUBJECTIVITY_SCORE': 0.01153846149408284, 'AVG_SENTENCE_LENGTH': 260.0, 'PERCENTAGE_COMPLEX_WORDS': 34.61538461538461, 'FOG_INDEX': 117.84615384615387, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 260.0, 'COMPLEX_WORD_COUNT': 90, 'WORD_COUNT': 260, 'SYLLABLE_PER_WORD': 2.226923076923077, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.926923076923077}
# ...
# {'URL_ID': 'bctech2129', 'URL': 'https://insights.blackcoffer.com/react-native-apps-in-the-development-portfolio/', 'POSITIVE_SCORE': 3, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999996666667778, 'SUBJECTIVITY_SCORE': 0.019354838584807493, 'AVG_SENTENCE_LENGTH': 155.0, 'PERCENTAGE_COMPLEX_WORDS': 41.935483870967744, 'FOG_INDEX': 78.7741935483871, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 155.0, 'COMPLEX_WORD_COUNT': 65, 'WORD_COUNT': 155, 'SYLLABLE_PER_WORD': 2.232258064516129, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.212903225806452}
# {'URL_ID': 'bctech2130', 'URL': 'https://insights.blackcoffer.com/a-leading-firm-website-seo-optimization/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.02551020395147855, 'AVG_SENTENCE_LENGTH': 196.0, 'PERCENTAGE_COMPLEX_WORDS': 43.87755102040816, 'FOG_INDEX': 95.95102040816327, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 196.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 196, 'SYLLABLE_PER_WORD': 2.3214285714285716, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.183673469387755}
# {'URL_ID': 'bctech2131', 'URL': 'https://insights.blackcoffer.com/a-leading-hospitality-firm-in-the-usa-website-seo-optimization/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.035175879220221716, 'AVG_SENTENCE_LENGTH': 199.0, 'PERCENTAGE_COMPLEX_WORDS': 42.211055276381906, 'FOG_INDEX': 96.48442211055277, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 199.0, 'COMPLEX_WORD_COUNT': 84, 'WORD_COUNT': 199, 'SYLLABLE_PER_WORD': 2.306532663316583, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.165829145728643}
# {'URL_ID': 'bctech2132', 'URL': 'https://insights.blackcoffer.com/a-leading-firm-in-the-usa-website-seo-optimization/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.4285713673469475, 'SUBJECTIVITY_SCORE': 0.03804347805411153, 'AVG_SENTENCE_LENGTH': 184.0, 'PERCENTAGE_COMPLEX_WORDS': 39.130434782608695, 'FOG_INDEX': 89.25217391304348, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 184.0, 'COMPLEX_WORD_COUNT': 72, 'WORD_COUNT': 184, 'SYLLABLE_PER_WORD': 2.217391304347826, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.016304347826087}
# {'URL_ID': 'bctech2133', 'URL': 'https://insights.blackcoffer.com/a-leading-musical-instrumental-website-seo-optimization/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.24999996875000394, 'SUBJECTIVITY_SCORE': 0.04255319126301494, 'AVG_SENTENCE_LENGTH': 188.0, 'PERCENTAGE_COMPLEX_WORDS': 44.680851063829785, 'FOG_INDEX': 93.07234042553192, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 188.0, 'COMPLEX_WORD_COUNT': 84, 'WORD_COUNT': 188, 'SYLLABLE_PER_WORD': 2.3404255319148937, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.170212765957447}
# {'URL_ID': 'bctech2134', 'URL': 'https://insights.blackcoffer.com/a-leading-firm-in-the-usa-seo-and-website-optimization/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.02747252732157952, 'AVG_SENTENCE_LENGTH': 182.0, 'PERCENTAGE_COMPLEX_WORDS': 43.40659340659341, 'FOG_INDEX': 90.16263736263737, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 182.0, 'COMPLEX_WORD_COUNT': 79, 'WORD_COUNT': 182, 'SYLLABLE_PER_WORD': 2.318681318681319, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.230769230769231}
# {'URL_ID': 'bctech2135', 'URL': 'https://insights.blackcoffer.com/immigration-datawarehouse-ai-based-recommendations/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999990000001, 'SUBJECTIVITY_SCORE': 0.03597122289218985, 'AVG_SENTENCE_LENGTH': 278.0, 'PERCENTAGE_COMPLEX_WORDS': 40.647482014388494, 'FOG_INDEX': 127.45899280575541, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 278.0, 'COMPLEX_WORD_COUNT': 113, 'WORD_COUNT': 278, 'SYLLABLE_PER_WORD': 2.338129496402878, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.079136690647482}
# {'URL_ID': 'bctech2136', 'URL': 'https://insights.blackcoffer.com/lipsync-automation-for-celebrities-and-influencers/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.018604651076257438, 'AVG_SENTENCE_LENGTH': 215.0, 'PERCENTAGE_COMPLEX_WORDS': 37.2093023255814, 'FOG_INDEX': 100.88372093023257, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 215.0, 'COMPLEX_WORD_COUNT': 80, 'WORD_COUNT': 215, 'SYLLABLE_PER_WORD': 2.302325581395349, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.046511627906977}
# {'URL_ID': 'bctech2137', 'URL': 'https://insights.blackcoffer.com/key-audit-matters-predictive-modeling/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 7, 'POLARITY_SCORE': -0.2727272479338866, 'SUBJECTIVITY_SCORE': 0.03013698621880278, 'AVG_SENTENCE_LENGTH': 365.0, 'PERCENTAGE_COMPLEX_WORDS': 39.178082191780824, 'FOG_INDEX': 161.67123287671234, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 365.0, 'COMPLEX_WORD_COUNT': 143, 'WORD_COUNT': 365, 'SYLLABLE_PER_WORD': 2.317808219178082, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.846575342465753}
# {'URL_ID': 'bctech2138', 'URL': 'https://insights.blackcoffer.com/splitting-of-songs-into-its-vocals-and-instrumental/', 'POSITIVE_SCORE': 11, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.6923076390532585, 'SUBJECTIVITY_SCORE': 0.05098039195693964, 'AVG_SENTENCE_LENGTH': 255.0, 'PERCENTAGE_COMPLEX_WORDS': 35.68627450980392, 'FOG_INDEX': 116.27450980392157, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 255.0, 'COMPLEX_WORD_COUNT': 91, 'WORD_COUNT': 255, 'SYLLABLE_PER_WORD': 2.2666666666666666, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.968627450980392}
# {'URL_ID': 'bctech2139', 'URL': 'https://insights.blackcoffer.com/ai-and-ml-technologies-to-evaluate-learning-assessments/', 'POSITIVE_SCORE': 13, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.7333332844444478, 'SUBJECTIVITY_SCORE': 0.04792332253059641, 'AVG_SENTENCE_LENGTH': 313.0, 'PERCENTAGE_COMPLEX_WORDS': 42.17252396166134, 'FOG_INDEX': 142.06900958466454, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 313.0, 'COMPLEX_WORD_COUNT': 132, 'WORD_COUNT': 313, 'SYLLABLE_PER_WORD': 2.4792332268370605, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.354632587859425}
# {'URL_ID': 'bctech2140', 'URL': 'https://insights.blackcoffer.com/datawarehouse-and-recommendations-engine-for-airbnb/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.6666666111111158, 'SUBJECTIVITY_SCORE': 0.04332129948259459, 'AVG_SENTENCE_LENGTH': 277.0, 'PERCENTAGE_COMPLEX_WORDS': 38.628158844765345, 'FOG_INDEX': 126.25126353790614, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 277.0, 'COMPLEX_WORD_COUNT': 107, 'WORD_COUNT': 277, 'SYLLABLE_PER_WORD': 2.3285198555956677, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.1046931407942235}
# {'URL_ID': 'bctech2141', 'URL': 'https://insights.blackcoffer.com/real-estate-data-warehouse/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.020905923272104797, 'AVG_SENTENCE_LENGTH': 287.0, 'PERCENTAGE_COMPLEX_WORDS': 38.67595818815331, 'FOG_INDEX': 130.2703832752613, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 287.0, 'COMPLEX_WORD_COUNT': 111, 'WORD_COUNT': 287, 'SYLLABLE_PER_WORD': 2.3310104529616726, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.031358885017422}
# {'URL_ID': 'bctech2142', 'URL': 'https://insights.blackcoffer.com/traction-dashboards-of-marketing-campaigns-and-posts/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.6666665555555741, 'SUBJECTIVITY_SCORE': 0.020905923272104797, 'AVG_SENTENCE_LENGTH': 287.0, 'PERCENTAGE_COMPLEX_WORDS': 34.84320557491289, 'FOG_INDEX': 128.73728222996516, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 287.0, 'COMPLEX_WORD_COUNT': 100, 'WORD_COUNT': 287, 'SYLLABLE_PER_WORD': 2.2369337979094075, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.979094076655052}
# {'URL_ID': 'bctech2143', 'URL': 'https://insights.blackcoffer.com/google-local-service-ads-lsa-data-warehouse/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.02222222212345679, 'AVG_SENTENCE_LENGTH': 225.0, 'PERCENTAGE_COMPLEX_WORDS': 40.44444444444444, 'FOG_INDEX': 106.17777777777779, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 225.0, 'COMPLEX_WORD_COUNT': 91, 'WORD_COUNT': 225, 'SYLLABLE_PER_WORD': 2.2933333333333334, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.946666666666666}
# {'URL_ID': 'bctech2144', 'URL': 'https://insights.blackcoffer.com/google-local-service-ads-missed-calls-and-messages-automation-tool/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.6666665555555741, 'SUBJECTIVITY_SCORE': 0.026431717945234724, 'AVG_SENTENCE_LENGTH': 227.0, 'PERCENTAGE_COMPLEX_WORDS': 37.88546255506608, 'FOG_INDEX': 105.95418502202642, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 227.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 227, 'SYLLABLE_PER_WORD': 2.2202643171806167, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.889867841409692}
# {'URL_ID': 'bctech2145', 'URL': 'https://insights.blackcoffer.com/marketing-ads-leads-call-status-data-tool-to-bigquery/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.023148148040980795, 'AVG_SENTENCE_LENGTH': 216.0, 'PERCENTAGE_COMPLEX_WORDS': 40.74074074074074, 'FOG_INDEX': 102.69629629629631, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 216.0, 'COMPLEX_WORD_COUNT': 88, 'WORD_COUNT': 216, 'SYLLABLE_PER_WORD': 2.314814814814815, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.060185185185185}
# {'URL_ID': 'bctech2146', 'URL': 'https://insights.blackcoffer.com/marketing-analytics-to-automate-leads-call-status-and-reporting/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.02252252242106972, 'AVG_SENTENCE_LENGTH': 222.0, 'PERCENTAGE_COMPLEX_WORDS': 38.73873873873874, 'FOG_INDEX': 104.2954954954955, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 222.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 222, 'SYLLABLE_PER_WORD': 2.2837837837837838, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.0675675675675675}
# {'URL_ID': 'bctech2147', 'URL': 'https://insights.blackcoffer.com/callrail-analytics-leads-report-alert/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.02304147454819597, 'AVG_SENTENCE_LENGTH': 217.0, 'PERCENTAGE_COMPLEX_WORDS': 39.63133640552996, 'FOG_INDEX': 102.652534562212, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 217.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 217, 'SYLLABLE_PER_WORD': 2.3179723502304146, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.082949308755761}
# {'URL_ID': 'bctech2148', 'URL': 'https://insights.blackcoffer.com/marketing-automation-tool-to-notify-lead-details-to-clients-over-email-and-phone/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.019801980099990197, 'AVG_SENTENCE_LENGTH': 202.0, 'PERCENTAGE_COMPLEX_WORDS': 40.099009900990104, 'FOG_INDEX': 96.83960396039605, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 202.0, 'COMPLEX_WORD_COUNT': 81, 'WORD_COUNT': 202, 'SYLLABLE_PER_WORD': 2.282178217821782, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.069306930693069}
# {'URL_ID': 'bctech2149', 'URL': 'https://insights.blackcoffer.com/data-etl-local-service-ads-leads-to-bigquery/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.024630541750588465, 'AVG_SENTENCE_LENGTH': 203.0, 'PERCENTAGE_COMPLEX_WORDS': 41.37931034482759, 'FOG_INDEX': 97.75172413793103, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 203.0, 'COMPLEX_WORD_COUNT': 84, 'WORD_COUNT': 203, 'SYLLABLE_PER_WORD': 2.310344827586207, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.068965517241379}
# {'URL_ID': 'bctech2150', 'URL': 'https://insights.blackcoffer.com/marbles-stimulation-using-python/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.4999999375000079, 'SUBJECTIVITY_SCORE': 0.032388663836483145, 'AVG_SENTENCE_LENGTH': 247.0, 'PERCENTAGE_COMPLEX_WORDS': 34.81781376518219, 'FOG_INDEX': 112.72712550607287, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 247.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 247, 'SYLLABLE_PER_WORD': 2.0890688259109313, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.582995951417004}
# {'URL_ID': 'bctech2151', 'URL': 'https://insights.blackcoffer.com/stocktwits-data-structurization/', 'POSITIVE_SCORE': 12, 'NEGATIVE_SCORE': 6, 'POLARITY_SCORE': 0.3333333148148158, 'SUBJECTIVITY_SCORE': 0.027820710930725332, 'AVG_SENTENCE_LENGTH': 647.0, 'PERCENTAGE_COMPLEX_WORDS': 31.839258114374037, 'FOG_INDEX': 271.53570324574963, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 647.0, 'COMPLEX_WORD_COUNT': 206, 'WORD_COUNT': 647, 'SYLLABLE_PER_WORD': 2.2117465224111283, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.727975270479135}
# {'URL_ID': 'bctech2152', 'URL': 'https://insights.blackcoffer.com/sentimental-analysis-on-shareholder-letter-of-companies/', 'POSITIVE_SCORE': 11, 'NEGATIVE_SCORE': 7, 'POLARITY_SCORE': 0.2222222098765439, 'SUBJECTIVITY_SCORE': 0.04186046501892915, 'AVG_SENTENCE_LENGTH': 430.0, 'PERCENTAGE_COMPLEX_WORDS': 46.04651162790698, 'FOG_INDEX': 190.4186046511628, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 430.0, 'COMPLEX_WORD_COUNT': 198, 'WORD_COUNT': 430, 'SYLLABLE_PER_WORD': 2.4, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.988372093023256}
# {'URL_ID': 'bctech2153', 'URL': 'https://insights.blackcoffer.com/population-and-community-survey-of-america/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 8, 'POLARITY_SCORE': 0.11111110493827195, 'SUBJECTIVITY_SCORE': 0.027272727231404958, 'AVG_SENTENCE_LENGTH': 660.0, 'PERCENTAGE_COMPLEX_WORDS': 38.18181818181819, 'FOG_INDEX': 279.2727272727273, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 660.0, 'COMPLEX_WORD_COUNT': 252, 'WORD_COUNT': 660, 'SYLLABLE_PER_WORD': 2.2015151515151516, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.631818181818182}
# {'URL_ID': 'bctech2154', 'URL': 'https://insights.blackcoffer.com/google-lsa-api-data-automation-and-dashboarding/', 'POSITIVE_SCORE': 14, 'NEGATIVE_SCORE': 9, 'POLARITY_SCORE': 0.21739129489603065, 'SUBJECTIVITY_SCORE': 0.024757804063769855, 'AVG_SENTENCE_LENGTH': 929.0, 'PERCENTAGE_COMPLEX_WORDS': 34.33799784714747, 'FOG_INDEX': 385.335199138859, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 929.0, 'COMPLEX_WORD_COUNT': 319, 'WORD_COUNT': 929, 'SYLLABLE_PER_WORD': 2.1743810548977396, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.5844994617868675}
# {'URL_ID': 'bctech2155', 'URL': 'https://insights.blackcoffer.com/healthcare-data-analysis/', 'POSITIVE_SCORE': 9, 'NEGATIVE_SCORE': 6, 'POLARITY_SCORE': 0.19999998666666757, 'SUBJECTIVITY_SCORE': 0.06302520981922181, 'AVG_SENTENCE_LENGTH': 238.0, 'PERCENTAGE_COMPLEX_WORDS': 36.97478991596639, 'FOG_INDEX': 109.98991596638655, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 238.0, 'COMPLEX_WORD_COUNT': 88, 'WORD_COUNT': 238, 'SYLLABLE_PER_WORD': 2.2394957983193278, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.9033613445378155}
# {'URL_ID': 'bctech2156', 'URL': 'https://insights.blackcoffer.com/budget-sales-kpi-dashboard-using-power-bi/', 'POSITIVE_SCORE': 3, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999996666667778, 'SUBJECTIVITY_SCORE': 0.020270270133308985, 'AVG_SENTENCE_LENGTH': 148.0, 'PERCENTAGE_COMPLEX_WORDS': 43.91891891891892, 'FOG_INDEX': 76.76756756756757, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 148.0, 'COMPLEX_WORD_COUNT': 65, 'WORD_COUNT': 148, 'SYLLABLE_PER_WORD': 2.445945945945946, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.6824324324324325}
# {'URL_ID': 'bctech2157', 'URL': 'https://insights.blackcoffer.com/amazon-buy-bot-an-automation-ai-tool-to-auto-checkouts/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.025252525124987248, 'AVG_SENTENCE_LENGTH': 198.0, 'PERCENTAGE_COMPLEX_WORDS': 39.39393939393939, 'FOG_INDEX': 94.95757575757575, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 198.0, 'COMPLEX_WORD_COUNT': 78, 'WORD_COUNT': 198, 'SYLLABLE_PER_WORD': 2.297979797979798, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.070707070707071}
# DataFrame saved successfully.

# %%
nltk.download('punkt')

def load_words(file_path, encoding='utf-8'):
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            words = file.read().splitlines()
    except UnicodeDecodeError:
        with open(file_path, 'r', encoding='ISO-8859-1') as file:
            words = file.read().splitlines()
    return set(words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Load stop words and sentiment words
stop_words = load_words('StopWords_Names.txt').union(
    load_words('StopWords_Geographic.txt'),
    load_words('StopWords_GenericLong.txt')
)

positive_words = load_words('positive-words.txt')
negative_words = load_words('negative-words.txt')

# %%
def read_article_text(url_id):
    try:
        with open(f'{url_id}.txt', 'r', encoding='utf-8') as file:
            text = file.read()
        return text
    except FileNotFoundError:
        print(f"File for URL_ID {url_id} not found.")
        return ""

# %%
def clean_text(text):
    words = word_tokenize(text)
    cleaned_text = [word for word in words if word.lower() not in stop_words and word.isalnum()]
    return ' '.join(cleaned_text)

# %%
def compute_sentiment_scores(cleaned_text):
    words = cleaned_text.split()
    positive_score = sum(1 for word in words if word in positive_words)
    negative_score = sum(1 for word in words if word in negative_words)
    polarity_score = (positive_score - negative_score) / (positive_score + negative_score + 1e-6)
    subjectivity_score = (positive_score + negative_score) / (len(words) + 1e-6)
    return positive_score, negative_score, polarity_score, subjectivity_score

# %%
def compute_readability_metrics(cleaned_text):
    sentences = sent_tokenize(cleaned_text)
    words = cleaned_text.split()
    avg_sentence_length = len(words) / len(sentences)
    complex_words = [word for word in words if len(re.findall(r'[aeiouy]+', word)) > 2]
    percentage_complex_words = len(complex_words) / len(words) * 100
    fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)
    avg_words_per_sentence = len(words) / len(sentences)
    complex_word_count = len(complex_words)
    word_count = len(words)
    syllable_count = sum([len(re.findall(r'[aeiouy]+', word)) for word in words])
    syllable_per_word = syllable_count / word_count
    personal_pronouns = len(re.findall(r'\b(I|we|my|ours|us)\b', cleaned_text, re.I))
    avg_word_length = sum(len(word) for word in words) / word_count

    return {
        'AVG_SENTENCE_LENGTH': avg_sentence_length,
        'PERCENTAGE_COMPLEX_WORDS': percentage_complex_words,
        'FOG_INDEX': fog_index,
        'AVG_NUMBER_OF_WORDS_PER_SENTENCE': avg_words_per_sentence,
        'COMPLEX_WORD_COUNT': complex_word_count,
        'WORD_COUNT': word_count,
        'SYLLABLE_PER_WORD': syllable_per_word,
        'PERSONAL_PRONOUNS': personal_pronouns,
        'AVG_WORD_LENGTH': avg_word_length
    }

output_df = pd.DataFrame(columns=[
    'URL_ID', 'URL', 'POSITIVE_SCORE', 'NEGATIVE_SCORE', 'POLARITY_SCORE', 'SUBJECTIVITY_SCORE',
    'AVG_SENTENCE_LENGTH', 'PERCENTAGE_COMPLEX_WORDS', 'FOG_INDEX', 'AVG_NUMBER_OF_WORDS_PER_SENTENCE',
    'COMPLEX_WORD_COUNT', 'WORD_COUNT', 'SYLLABLE_PER_WORD', 'PERSONAL_PRONOUNS', 'AVG_WORD_LENGTH'
])

# %%
# Read the input file
input_df = pd.read_excel('Input.xlsx')
urls = input_df['URL']
url_ids = input_df['URL_ID']

for url_id, url in zip(url_ids, urls):
    text = read_article_text(url_id)
    if text.strip():
        cleaned_text = clean_text(text)
        pos_score, neg_score, pol_score, subj_score = compute_sentiment_scores(cleaned_text)
        readability_metrics = compute_readability_metrics(cleaned_text)

        row = {
            'URL_ID': url_id, 'URL': url, 'POSITIVE_SCORE': pos_score, 'NEGATIVE_SCORE': neg_score,
            'POLARITY_SCORE': pol_score, 'SUBJECTIVITY_SCORE': subj_score, **readability_metrics
        }
        print(row)
        output_df = pd.concat([output_df, pd.DataFrame([row])], ignore_index=True)
    else:
        print(f"No text extracted for URL_ID {url_id}.")
# Out:
# {'URL_ID': 'bctech2011', 'URL': 'https://insights.blackcoffer.com/ml-and-ai-based-insurance-premium-model-to-predict-premium-to-be-charged-by-the-insurance-company/', 'POSITIVE_SCORE': 34, 'NEGATIVE_SCORE': 8, 'POLARITY_SCORE': 0.6190476043083905, 'SUBJECTIVITY_SCORE': 0.07155025541473552, 'AVG_SENTENCE_LENGTH': 587.0, 'PERCENTAGE_COMPLEX_WORDS': 51.618398637137986, 'FOG_INDEX': 255.4473594548552, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 587.0, 'COMPLEX_WORD_COUNT': 303, 'WORD_COUNT': 587, 'SYLLABLE_PER_WORD': 2.5928449744463373, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.630323679727428}
# {'URL_ID': 'bctech2012', 'URL': 'https://insights.blackcoffer.com/streamlined-integration-interactive-brokers-api-with-python-for-desktop-trading-application/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.021390374217163773, 'AVG_SENTENCE_LENGTH': 187.0, 'PERCENTAGE_COMPLEX_WORDS': 42.780748663101605, 'FOG_INDEX': 91.91229946524065, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 187.0, 'COMPLEX_WORD_COUNT': 80, 'WORD_COUNT': 187, 'SYLLABLE_PER_WORD': 2.3475935828877006, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.491978609625669}
# {'URL_ID': 'bctech2013', 'URL': 'https://insights.blackcoffer.com/efficient-data-integration-and-user-friendly-interface-development-navigating-challenges-in-web-application-deployment/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.02162162150474799, 'AVG_SENTENCE_LENGTH': 185.0, 'PERCENTAGE_COMPLEX_WORDS': 44.32432432432433, 'FOG_INDEX': 91.72972972972974, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 185.0, 'COMPLEX_WORD_COUNT': 82, 'WORD_COUNT': 185, 'SYLLABLE_PER_WORD': 2.3675675675675674, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.524324324324325}
# {'URL_ID': 'bctech2014', 'URL': 'https://insights.blackcoffer.com/effective-management-of-social-media-data-extraction-strategies-for-authentication-security-and-reliability/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.021390374217163773, 'AVG_SENTENCE_LENGTH': 187.0, 'PERCENTAGE_COMPLEX_WORDS': 43.85026737967914, 'FOG_INDEX': 92.34010695187166, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 187.0, 'COMPLEX_WORD_COUNT': 82, 'WORD_COUNT': 187, 'SYLLABLE_PER_WORD': 2.390374331550802, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.518716577540107}
# {'URL_ID': 'bctech2015', 'URL': 'https://insights.blackcoffer.com/streamlined-trading-operations-interface-for-metatrader-4-empowering-efficient-management-and-monitoring/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.02127659563150747, 'AVG_SENTENCE_LENGTH': 188.0, 'PERCENTAGE_COMPLEX_WORDS': 44.148936170212764, 'FOG_INDEX': 92.85957446808511, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 188.0, 'COMPLEX_WORD_COUNT': 83, 'WORD_COUNT': 188, 'SYLLABLE_PER_WORD': 2.372340425531915, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.537234042553192}
# {'URL_ID': 'bctech2016', 'URL': 'https://insights.blackcoffer.com/efficient-aws-infrastructure-setup-and-management-addressing-security-scalability-and-compliance/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.02173913031663516, 'AVG_SENTENCE_LENGTH': 184.0, 'PERCENTAGE_COMPLEX_WORDS': 44.02173913043478, 'FOG_INDEX': 91.20869565217392, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 184.0, 'COMPLEX_WORD_COUNT': 81, 'WORD_COUNT': 184, 'SYLLABLE_PER_WORD': 2.380434782608696, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.554347826086956}
# {'URL_ID': 'bctech2017', 'URL': 'https://insights.blackcoffer.com/streamlined-equity-waterfall-calculation-and-deal-management-system/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.02127659563150747, 'AVG_SENTENCE_LENGTH': 188.0, 'PERCENTAGE_COMPLEX_WORDS': 43.08510638297872, 'FOG_INDEX': 92.43404255319149, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 188.0, 'COMPLEX_WORD_COUNT': 81, 'WORD_COUNT': 188, 'SYLLABLE_PER_WORD': 2.345744680851064, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.4361702127659575}
# {'URL_ID': 'bctech2018', 'URL': 'https://insights.blackcoffer.com/automated-orthopedic-case-report-generation-harnessing-web-scraping-and-ai-integration/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.021390374217163773, 'AVG_SENTENCE_LENGTH': 187.0, 'PERCENTAGE_COMPLEX_WORDS': 44.38502673796791, 'FOG_INDEX': 92.55401069518717, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 187.0, 'COMPLEX_WORD_COUNT': 83, 'WORD_COUNT': 187, 'SYLLABLE_PER_WORD': 2.3636363636363638, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.481283422459893}
# {'URL_ID': 'bctech2019', 'URL': 'https://insights.blackcoffer.com/streamlining-time-calculation-in-warehouse-management-leveraging-shiphero-api-and-google-bigquery-integration/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.02040816316118284, 'AVG_SENTENCE_LENGTH': 196.0, 'PERCENTAGE_COMPLEX_WORDS': 43.87755102040816, 'FOG_INDEX': 95.95102040816327, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 196.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 196, 'SYLLABLE_PER_WORD': 2.372448979591837, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.469387755102041}
# {'URL_ID': 'bctech2020', 'URL': 'https://insights.blackcoffer.com/efficient-database-design-and-management-streamlining-access-and-integration-for-partner-entity-management/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.021390374217163773, 'AVG_SENTENCE_LENGTH': 187.0, 'PERCENTAGE_COMPLEX_WORDS': 44.38502673796791, 'FOG_INDEX': 92.55401069518717, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 187.0, 'COMPLEX_WORD_COUNT': 83, 'WORD_COUNT': 187, 'SYLLABLE_PER_WORD': 2.3850267379679146, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.540106951871658}
# {'URL_ID': 'bctech2021', 'URL': 'https://insights.blackcoffer.com/automated-campaign-management-system-a-comprehensive-solution-with-linkedin-and-email-integration/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.020942408267317233, 'AVG_SENTENCE_LENGTH': 191.0, 'PERCENTAGE_COMPLEX_WORDS': 44.50261780104712, 'FOG_INDEX': 94.20104712041885, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 191.0, 'COMPLEX_WORD_COUNT': 85, 'WORD_COUNT': 191, 'SYLLABLE_PER_WORD': 2.3821989528795813, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.513089005235602}
# {'URL_ID': 'bctech2022', 'URL': 'https://insights.blackcoffer.com/ai-driven-data-analysis-ai-tool-using-langchain-for-a-leading-real-estate-and-financing-firm-worldwide/', 'POSITIVE_SCORE': 19, 'NEGATIVE_SCORE': 4, 'POLARITY_SCORE': 0.6521738846880919, 'SUBJECTIVITY_SCORE': 0.047034764729990255, 'AVG_SENTENCE_LENGTH': 489.0, 'PERCENTAGE_COMPLEX_WORDS': 41.308793456032724, 'FOG_INDEX': 212.1235173824131, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 489.0, 'COMPLEX_WORD_COUNT': 202, 'WORD_COUNT': 489, 'SYLLABLE_PER_WORD': 2.3885480572597135, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.139059304703476}
# {'URL_ID': 'bctech2023', 'URL': 'https://insights.blackcoffer.com/grafana-dashboard-to-visualize-and-analyze-sensors-data/', 'POSITIVE_SCORE': 19, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.7272726942148775, 'SUBJECTIVITY_SCORE': 0.060606060439101765, 'AVG_SENTENCE_LENGTH': 363.0, 'PERCENTAGE_COMPLEX_WORDS': 44.90358126721763, 'FOG_INDEX': 163.16143250688708, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 363.0, 'COMPLEX_WORD_COUNT': 163, 'WORD_COUNT': 363, 'SYLLABLE_PER_WORD': 2.4077134986225897, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.203856749311295}
# {'URL_ID': 'bctech2024', 'URL': 'https://insights.blackcoffer.com/mvp-for-a-software-that-analyses-content-from-audio-pharma-based/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.39999996000000404, 'SUBJECTIVITY_SCORE': 0.037593984821075246, 'AVG_SENTENCE_LENGTH': 266.0, 'PERCENTAGE_COMPLEX_WORDS': 43.609022556390975, 'FOG_INDEX': 123.8436090225564, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 266.0, 'COMPLEX_WORD_COUNT': 116, 'WORD_COUNT': 266, 'SYLLABLE_PER_WORD': 2.3609022556390977, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.327067669172933}
# {'URL_ID': 'bctech2025', 'URL': 'https://insights.blackcoffer.com/data-engineering-and-management-tool-airbyte-with-custom-data-connectors-to-manage-crm-database/', 'POSITIVE_SCORE': 20, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.8181817809917372, 'SUBJECTIVITY_SCORE': 0.04856512130559576, 'AVG_SENTENCE_LENGTH': 453.0, 'PERCENTAGE_COMPLEX_WORDS': 48.12362030905077, 'FOG_INDEX': 200.4494481236203, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 453.0, 'COMPLEX_WORD_COUNT': 218, 'WORD_COUNT': 453, 'SYLLABLE_PER_WORD': 2.4944812362030904, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.2759381898454745}
# {'URL_ID': 'bctech2026', 'URL': 'https://insights.blackcoffer.com/text-summarizing-tool-to-scrape-and-summarize-pubmed-medical-papers/', 'POSITIVE_SCORE': 31, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.8235293875432533, 'SUBJECTIVITY_SCORE': 0.07925407906933782, 'AVG_SENTENCE_LENGTH': 429.0, 'PERCENTAGE_COMPLEX_WORDS': 43.58974358974359, 'FOG_INDEX': 189.03589743589745, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 429.0, 'COMPLEX_WORD_COUNT': 187, 'WORD_COUNT': 429, 'SYLLABLE_PER_WORD': 2.41025641025641, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.4125874125874125}
# {'URL_ID': 'bctech2027', 'URL': 'https://insights.blackcoffer.com/7up7down-10updown-snakes-and-ladder-games-built-using-oops/', 'POSITIVE_SCORE': 20, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.9047618616780065, 'SUBJECTIVITY_SCORE': 0.053030302896388125, 'AVG_SENTENCE_LENGTH': 396.0, 'PERCENTAGE_COMPLEX_WORDS': 45.45454545454545, 'FOG_INDEX': 176.5818181818182, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 396.0, 'COMPLEX_WORD_COUNT': 180, 'WORD_COUNT': 396, 'SYLLABLE_PER_WORD': 2.3914141414141414, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.25}
# {'URL_ID': 'bctech2028', 'URL': 'https://insights.blackcoffer.com/data-studio-dashboard-with-a-data-pipeline-tool-synced-with-podio-using-custom-webhooks-and-google-cloud-function/', 'POSITIVE_SCORE': 24, 'NEGATIVE_SCORE': 4, 'POLARITY_SCORE': 0.7142856887755111, 'SUBJECTIVITY_SCORE': 0.05702647646226787, 'AVG_SENTENCE_LENGTH': 491.0, 'PERCENTAGE_COMPLEX_WORDS': 41.955193482688394, 'FOG_INDEX': 213.18207739307536, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 491.0, 'COMPLEX_WORD_COUNT': 206, 'WORD_COUNT': 491, 'SYLLABLE_PER_WORD': 2.4114052953156824, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.256619144602851}
# {'URL_ID': 'bctech2029', 'URL': 'https://insights.blackcoffer.com/end-to-end-tool-to-optimize-routing-and-planning-of-field-engineers-using-googles-cvrp-tw-algorithm/', 'POSITIVE_SCORE': 32, 'NEGATIVE_SCORE': 7, 'POLARITY_SCORE': 0.6410256245890866, 'SUBJECTIVITY_SCORE': 0.09027777756880144, 'AVG_SENTENCE_LENGTH': 432.0, 'PERCENTAGE_COMPLEX_WORDS': 49.30555555555556, 'FOG_INDEX': 192.52222222222224, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 432.0, 'COMPLEX_WORD_COUNT': 213, 'WORD_COUNT': 432, 'SYLLABLE_PER_WORD': 2.525462962962963, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.506944444444445}
# {'URL_ID': 'bctech2030', 'URL': 'https://insights.blackcoffer.com/end-to-end-tool-to-predict-biofuel-prices-using-ieso-data/', 'POSITIVE_SCORE': 26, 'NEGATIVE_SCORE': 7, 'POLARITY_SCORE': 0.5757575583103771, 'SUBJECTIVITY_SCORE': 0.07096774178286507, 'AVG_SENTENCE_LENGTH': 465.0, 'PERCENTAGE_COMPLEX_WORDS': 41.935483870967744, 'FOG_INDEX': 202.7741935483871, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 465.0, 'COMPLEX_WORD_COUNT': 195, 'WORD_COUNT': 465, 'SYLLABLE_PER_WORD': 2.3806451612903228, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.193548387096774}
# {'URL_ID': 'bctech2031', 'URL': 'https://insights.blackcoffer.com/etl-discovery-tool-using-llma-langchain-openai/', 'POSITIVE_SCORE': 24, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.8461538136094686, 'SUBJECTIVITY_SCORE': 0.04896421836353255, 'AVG_SENTENCE_LENGTH': 531.0, 'PERCENTAGE_COMPLEX_WORDS': 40.11299435028249, 'FOG_INDEX': 228.44519774011303, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 531.0, 'COMPLEX_WORD_COUNT': 213, 'WORD_COUNT': 531, 'SYLLABLE_PER_WORD': 2.2598870056497176, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.062146892655368}
# {'URL_ID': 'bctech2032', 'URL': 'https://insights.blackcoffer.com/gpt-ocr-api/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.018656716348295833, 'AVG_SENTENCE_LENGTH': 268.0, 'PERCENTAGE_COMPLEX_WORDS': 41.417910447761194, 'FOG_INDEX': 123.76716417910448, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 268.0, 'COMPLEX_WORD_COUNT': 111, 'WORD_COUNT': 268, 'SYLLABLE_PER_WORD': 2.2388059701492535, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.985074626865671}
# {'URL_ID': 'bctech2033', 'URL': 'https://insights.blackcoffer.com/dockerize-the-aws-lambda-for-serverless-architecture/', 'POSITIVE_SCORE': 11, 'NEGATIVE_SCORE': 7, 'POLARITY_SCORE': 0.2222222098765439, 'SUBJECTIVITY_SCORE': 0.04699738891123397, 'AVG_SENTENCE_LENGTH': 383.0, 'PERCENTAGE_COMPLEX_WORDS': 49.60835509138381, 'FOG_INDEX': 173.04334203655355, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 383.0, 'COMPLEX_WORD_COUNT': 190, 'WORD_COUNT': 383, 'SYLLABLE_PER_WORD': 2.5613577023498695, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.68668407310705}
# {'URL_ID': 'bctech2034', 'URL': 'https://insights.blackcoffer.com/design-and-develop-a-product-recommendation-engine-based-on-the-features-of-products/', 'POSITIVE_SCORE': 20, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999999500000024, 'SUBJECTIVITY_SCORE': 0.06042296054252882, 'AVG_SENTENCE_LENGTH': 331.0, 'PERCENTAGE_COMPLEX_WORDS': 46.52567975830816, 'FOG_INDEX': 151.0102719033233, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 331.0, 'COMPLEX_WORD_COUNT': 154, 'WORD_COUNT': 331, 'SYLLABLE_PER_WORD': 2.4531722054380665, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.404833836858006}
# {'URL_ID': 'bctech2035', 'URL': 'https://insights.blackcoffer.com/database-discovery-tool-using-openai/', 'POSITIVE_SCORE': 15, 'NEGATIVE_SCORE': 5, 'POLARITY_SCORE': 0.4999999750000012, 'SUBJECTIVITY_SCORE': 0.05221932101248219, 'AVG_SENTENCE_LENGTH': 383.0, 'PERCENTAGE_COMPLEX_WORDS': 46.47519582245431, 'FOG_INDEX': 171.79007832898174, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 383.0, 'COMPLEX_WORD_COUNT': 178, 'WORD_COUNT': 383, 'SYLLABLE_PER_WORD': 2.4673629242819843, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.295039164490862}
# {'URL_ID': 'bctech2036', 'URL': 'https://insights.blackcoffer.com/automate-the-data-management-process/', 'POSITIVE_SCORE': 17, 'NEGATIVE_SCORE': 9, 'POLARITY_SCORE': 0.30769229585798863, 'SUBJECTIVITY_SCORE': 0.055319148818469895, 'AVG_SENTENCE_LENGTH': 470.0, 'PERCENTAGE_COMPLEX_WORDS': 43.61702127659575, 'FOG_INDEX': 205.44680851063833, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 470.0, 'COMPLEX_WORD_COUNT': 205, 'WORD_COUNT': 470, 'SYLLABLE_PER_WORD': 2.480851063829787, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.223404255319149}
# {'URL_ID': 'bctech2037', 'URL': 'https://insights.blackcoffer.com/realtime-kibana-dashboard-for-a-financial-tech-firm/', 'POSITIVE_SCORE': 20, 'NEGATIVE_SCORE': 14, 'POLARITY_SCORE': 0.17647058304498286, 'SUBJECTIVITY_SCORE': 0.05841924388587759, 'AVG_SENTENCE_LENGTH': 582.0, 'PERCENTAGE_COMPLEX_WORDS': 35.051546391752574, 'FOG_INDEX': 246.82061855670105, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 582.0, 'COMPLEX_WORD_COUNT': 204, 'WORD_COUNT': 582, 'SYLLABLE_PER_WORD': 2.2216494845360826, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.702749140893471}
# {'URL_ID': 'bctech2038', 'URL': 'https://insights.blackcoffer.com/data-management-etl-and-data-automation/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.024390243817455595, 'AVG_SENTENCE_LENGTH': 287.0, 'PERCENTAGE_COMPLEX_WORDS': 35.54006968641115, 'FOG_INDEX': 129.01602787456446, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 287.0, 'COMPLEX_WORD_COUNT': 102, 'WORD_COUNT': 287, 'SYLLABLE_PER_WORD': 2.163763066202091, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.923344947735192}
# {'URL_ID': 'bctech2039', 'URL': 'https://insights.blackcoffer.com/data-management-egeas/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.02745098028450596, 'AVG_SENTENCE_LENGTH': 255.0, 'PERCENTAGE_COMPLEX_WORDS': 35.294117647058826, 'FOG_INDEX': 116.11764705882354, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 255.0, 'COMPLEX_WORD_COUNT': 90, 'WORD_COUNT': 255, 'SYLLABLE_PER_WORD': 2.1098039215686275, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.113725490196078}
# {'URL_ID': 'bctech2040', 'URL': 'https://insights.blackcoffer.com/design-and-develop-powershell-script/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.02489626545686197, 'AVG_SENTENCE_LENGTH': 241.0, 'PERCENTAGE_COMPLEX_WORDS': 36.51452282157676, 'FOG_INDEX': 111.0058091286307, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 241.0, 'COMPLEX_WORD_COUNT': 88, 'WORD_COUNT': 241, 'SYLLABLE_PER_WORD': 2.224066390041494, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.045643153526971}
# {'URL_ID': 'bctech2041', 'URL': 'https://insights.blackcoffer.com/design-and-develop-jenkins-shared-library/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.03389830489322992, 'AVG_SENTENCE_LENGTH': 177.0, 'PERCENTAGE_COMPLEX_WORDS': 40.67796610169492, 'FOG_INDEX': 87.07118644067798, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 177.0, 'COMPLEX_WORD_COUNT': 72, 'WORD_COUNT': 177, 'SYLLABLE_PER_WORD': 2.3220338983050848, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.288135593220339}
# {'URL_ID': 'bctech2042', 'URL': 'https://insights.blackcoffer.com/design-and-develop-retool-app-for-wholecell-io-and-asana-data-using-their-apis/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.028037383046554284, 'AVG_SENTENCE_LENGTH': 214.0, 'PERCENTAGE_COMPLEX_WORDS': 35.51401869158878, 'FOG_INDEX': 99.80560747663552, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 214.0, 'COMPLEX_WORD_COUNT': 76, 'WORD_COUNT': 214, 'SYLLABLE_PER_WORD': 2.2383177570093458, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.9766355140186915}
# {'URL_ID': 'bctech2043', 'URL': 'https://insights.blackcoffer.com/design-and-develop-a-retool-app-that-will-show-stock-and-crypto-related-information-using-iex-api/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.025089605644840123, 'AVG_SENTENCE_LENGTH': 279.0, 'PERCENTAGE_COMPLEX_WORDS': 32.61648745519714, 'FOG_INDEX': 124.64659498207887, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 279.0, 'COMPLEX_WORD_COUNT': 91, 'WORD_COUNT': 279, 'SYLLABLE_PER_WORD': 2.082437275985663, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.530465949820789}
# {'URL_ID': 'bctech2044', 'URL': 'https://insights.blackcoffer.com/crm-monday-com-make-com-to-data-warehouse-to-klipfolio-dashboard/', 'POSITIVE_SCORE': 11, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.8333332638888947, 'SUBJECTIVITY_SCORE': 0.03183023864236011, 'AVG_SENTENCE_LENGTH': 377.0, 'PERCENTAGE_COMPLEX_WORDS': 32.891246684350136, 'FOG_INDEX': 163.95649867374004, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 377.0, 'COMPLEX_WORD_COUNT': 124, 'WORD_COUNT': 377, 'SYLLABLE_PER_WORD': 2.0689655172413794, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.941644562334218}
# {'URL_ID': 'bctech2045', 'URL': 'https://insights.blackcoffer.com/ner-task-using-bert-with-data-in-xml-format/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.02583025820726842, 'AVG_SENTENCE_LENGTH': 271.0, 'PERCENTAGE_COMPLEX_WORDS': 38.00738007380074, 'FOG_INDEX': 123.6029520295203, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 271.0, 'COMPLEX_WORD_COUNT': 103, 'WORD_COUNT': 271, 'SYLLABLE_PER_WORD': 2.2029520295202953, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.948339483394834}
# {'URL_ID': 'bctech2046', 'URL': 'https://insights.blackcoffer.com/qualtrics-api-integration-using-python/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.026086956408317583, 'AVG_SENTENCE_LENGTH': 230.0, 'PERCENTAGE_COMPLEX_WORDS': 37.391304347826086, 'FOG_INDEX': 106.95652173913044, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 230.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 230, 'SYLLABLE_PER_WORD': 2.256521739130435, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.1695652173913045}
# {'URL_ID': 'bctech2047', 'URL': 'https://insights.blackcoffer.com/design-and-develop-mlops-framework-for-data-centric-ai/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.7499999062500118, 'SUBJECTIVITY_SCORE': 0.029197080185412116, 'AVG_SENTENCE_LENGTH': 274.0, 'PERCENTAGE_COMPLEX_WORDS': 39.416058394160586, 'FOG_INDEX': 125.36642335766425, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 274.0, 'COMPLEX_WORD_COUNT': 108, 'WORD_COUNT': 274, 'SYLLABLE_PER_WORD': 2.281021897810219, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.1678832116788325}
# {'URL_ID': 'bctech2048', 'URL': 'https://insights.blackcoffer.com/nlp-based-approach-for-data-transformation/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.7499999062500118, 'SUBJECTIVITY_SCORE': 0.03319502060914929, 'AVG_SENTENCE_LENGTH': 241.0, 'PERCENTAGE_COMPLEX_WORDS': 36.51452282157676, 'FOG_INDEX': 111.0058091286307, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 241.0, 'COMPLEX_WORD_COUNT': 88, 'WORD_COUNT': 241, 'SYLLABLE_PER_WORD': 2.2448132780082988, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.979253112033195}
# {'URL_ID': 'bctech2049', 'URL': 'https://insights.blackcoffer.com/an-etl-tool-to-pull-data-from-shiphero-to-google-bigquery-data-warehouse/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.5384614970414233, 'SUBJECTIVITY_SCORE': 0.038123167043627074, 'AVG_SENTENCE_LENGTH': 341.0, 'PERCENTAGE_COMPLEX_WORDS': 38.41642228739003, 'FOG_INDEX': 151.76656891495603, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 341.0, 'COMPLEX_WORD_COUNT': 131, 'WORD_COUNT': 341, 'SYLLABLE_PER_WORD': 2.313782991202346, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.941348973607038}
# {'URL_ID': 'bctech2050', 'URL': 'https://insights.blackcoffer.com/plaid-financial-analytics-a-data-driven-dashboard-to-generate-insights/', 'POSITIVE_SCORE': 9, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.7999999200000081, 'SUBJECTIVITY_SCORE': 0.03663003649586067, 'AVG_SENTENCE_LENGTH': 273.0, 'PERCENTAGE_COMPLEX_WORDS': 39.56043956043956, 'FOG_INDEX': 125.02417582417584, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 273.0, 'COMPLEX_WORD_COUNT': 108, 'WORD_COUNT': 273, 'SYLLABLE_PER_WORD': 2.3443223443223444, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.131868131868132}
# {'URL_ID': 'bctech2051', 'URL': 'https://insights.blackcoffer.com/recommendation-engine-for-insurance-sector-to-expand-business-in-the-rural-area/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.8181817438016598, 'SUBJECTIVITY_SCORE': 0.034374999892578126, 'AVG_SENTENCE_LENGTH': 320.0, 'PERCENTAGE_COMPLEX_WORDS': 42.5, 'FOG_INDEX': 145.0, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 320.0, 'COMPLEX_WORD_COUNT': 136, 'WORD_COUNT': 320, 'SYLLABLE_PER_WORD': 2.396875, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.24375}
# {'URL_ID': 'bctech2052', 'URL': 'https://insights.blackcoffer.com/data-from-crm-via-zapier-to-google-sheets-dynamic-to-powerbi/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999990000001, 'SUBJECTIVITY_SCORE': 0.038759689772249264, 'AVG_SENTENCE_LENGTH': 258.0, 'PERCENTAGE_COMPLEX_WORDS': 32.945736434108525, 'FOG_INDEX': 116.37829457364342, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 258.0, 'COMPLEX_WORD_COUNT': 85, 'WORD_COUNT': 258, 'SYLLABLE_PER_WORD': 2.1744186046511627, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.887596899224806}
# {'URL_ID': 'bctech2053', 'URL': 'https://insights.blackcoffer.com/data-warehouse-to-google-data-studio-looker-dashboard/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.02447552438994572, 'AVG_SENTENCE_LENGTH': 286.0, 'PERCENTAGE_COMPLEX_WORDS': 34.61538461538461, 'FOG_INDEX': 128.24615384615387, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 286.0, 'COMPLEX_WORD_COUNT': 99, 'WORD_COUNT': 286, 'SYLLABLE_PER_WORD': 2.2132867132867133, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.006993006993007}
# {'URL_ID': 'bctech2054', 'URL': 'https://insights.blackcoffer.com/crm-monday-com-via-zapier-to-power-bi-dashboard/', 'POSITIVE_SCORE': 14, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.6470587854671302, 'SUBJECTIVITY_SCORE': 0.055921052447628114, 'AVG_SENTENCE_LENGTH': 304.0, 'PERCENTAGE_COMPLEX_WORDS': 29.93421052631579, 'FOG_INDEX': 133.57368421052632, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 304.0, 'COMPLEX_WORD_COUNT': 91, 'WORD_COUNT': 304, 'SYLLABLE_PER_WORD': 2.0526315789473686, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.707236842105263}
# {'URL_ID': 'bctech2055', 'URL': 'https://insights.blackcoffer.com/monday-com-to-kpi-dashboard-to-manage-view-and-generate-insights-from-the-crm-data/', 'POSITIVE_SCORE': 18, 'NEGATIVE_SCORE': 6, 'POLARITY_SCORE': 0.4999999791666675, 'SUBJECTIVITY_SCORE': 0.07476635490726992, 'AVG_SENTENCE_LENGTH': 321.0, 'PERCENTAGE_COMPLEX_WORDS': 35.202492211838006, 'FOG_INDEX': 142.48099688473522, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 321.0, 'COMPLEX_WORD_COUNT': 113, 'WORD_COUNT': 321, 'SYLLABLE_PER_WORD': 2.102803738317757, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.735202492211838}
# {'URL_ID': 'bctech2056', 'URL': 'https://insights.blackcoffer.com/data-management-for-a-political-saas-application/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.33333329629630043, 'SUBJECTIVITY_SCORE': 0.02623906697889485, 'AVG_SENTENCE_LENGTH': 343.0, 'PERCENTAGE_COMPLEX_WORDS': 39.067055393586, 'FOG_INDEX': 152.8268221574344, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 343.0, 'COMPLEX_WORD_COUNT': 134, 'WORD_COUNT': 343, 'SYLLABLE_PER_WORD': 2.253644314868805, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.982507288629738}
# {'URL_ID': 'bctech2057', 'URL': 'https://insights.blackcoffer.com/google-lsa-ads-google-local-service-ads-etl-tools-and-dashboards/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.021660649741297295, 'AVG_SENTENCE_LENGTH': 277.0, 'PERCENTAGE_COMPLEX_WORDS': 36.101083032490976, 'FOG_INDEX': 125.2404332129964, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 277.0, 'COMPLEX_WORD_COUNT': 100, 'WORD_COUNT': 277, 'SYLLABLE_PER_WORD': 2.2021660649819497, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.963898916967509}
# {'URL_ID': 'bctech2058', 'URL': 'https://insights.blackcoffer.com/ad-networks-marketing-campaign-data-dashboard-in-looker-google-data-studio/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.029126213450843624, 'AVG_SENTENCE_LENGTH': 206.0, 'PERCENTAGE_COMPLEX_WORDS': 38.349514563106794, 'FOG_INDEX': 97.73980582524273, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 206.0, 'COMPLEX_WORD_COUNT': 79, 'WORD_COUNT': 206, 'SYLLABLE_PER_WORD': 2.266990291262136, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.194174757281553}
# {'URL_ID': 'bctech2059', 'URL': 'https://insights.blackcoffer.com/analytical-solution-for-a-tech-firm/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.5555554938271674, 'SUBJECTIVITY_SCORE': 0.0473684208033241, 'AVG_SENTENCE_LENGTH': 190.0, 'PERCENTAGE_COMPLEX_WORDS': 40.526315789473685, 'FOG_INDEX': 92.21052631578948, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 190.0, 'COMPLEX_WORD_COUNT': 77, 'WORD_COUNT': 190, 'SYLLABLE_PER_WORD': 2.3105263157894735, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.331578947368421}
# {'URL_ID': 'bctech2060', 'URL': 'https://insights.blackcoffer.com/ai-solution-for-a-technology-information-and-internet-firm/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.028985507106350207, 'AVG_SENTENCE_LENGTH': 207.0, 'PERCENTAGE_COMPLEX_WORDS': 40.09661835748793, 'FOG_INDEX': 98.83864734299517, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 207.0, 'COMPLEX_WORD_COUNT': 83, 'WORD_COUNT': 207, 'SYLLABLE_PER_WORD': 2.289855072463768, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.1980676328502415}
# {'URL_ID': 'bctech2061', 'URL': 'https://insights.blackcoffer.com/ai-and-nlp-based-solutions-to-automate-data-discovery-for-venture-capital-and-private-equity-principals/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.026615969480547643, 'AVG_SENTENCE_LENGTH': 263.0, 'PERCENTAGE_COMPLEX_WORDS': 44.866920152091254, 'FOG_INDEX': 123.14676806083651, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 263.0, 'COMPLEX_WORD_COUNT': 118, 'WORD_COUNT': 263, 'SYLLABLE_PER_WORD': 2.365019011406844, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.266159695817491}
# {'URL_ID': 'bctech2062', 'URL': 'https://insights.blackcoffer.com/an-etl-solution-for-an-internet-publishing-firm/', 'POSITIVE_SCORE': 12, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999999166666736, 'SUBJECTIVITY_SCORE': 0.039603960265333464, 'AVG_SENTENCE_LENGTH': 303.0, 'PERCENTAGE_COMPLEX_WORDS': 34.65346534653465, 'FOG_INDEX': 135.06138613861387, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 303.0, 'COMPLEX_WORD_COUNT': 105, 'WORD_COUNT': 303, 'SYLLABLE_PER_WORD': 2.221122112211221, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.702970297029703}
# {'URL_ID': 'bctech2063', 'URL': 'https://insights.blackcoffer.com/ai-based-algorithmic-trading-bot-for-forex/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.02857142843537415, 'AVG_SENTENCE_LENGTH': 210.0, 'PERCENTAGE_COMPLEX_WORDS': 37.61904761904762, 'FOG_INDEX': 99.04761904761905, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 210.0, 'COMPLEX_WORD_COUNT': 79, 'WORD_COUNT': 210, 'SYLLABLE_PER_WORD': 2.2714285714285714, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.171428571428572}
# {'URL_ID': 'bctech2064', 'URL': 'https://insights.blackcoffer.com/equity-waterfalls-model-based-saas-application-for-real-estate-sector/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.33333329629630043, 'SUBJECTIVITY_SCORE': 0.028938906659360428, 'AVG_SENTENCE_LENGTH': 311.0, 'PERCENTAGE_COMPLEX_WORDS': 41.157556270096464, 'FOG_INDEX': 140.8630225080386, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 311.0, 'COMPLEX_WORD_COUNT': 128, 'WORD_COUNT': 311, 'SYLLABLE_PER_WORD': 2.302250803858521, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.048231511254019}
# {'URL_ID': 'bctech2065', 'URL': 'https://insights.blackcoffer.com/ai-solutions-for-foreign-exchange-an-automated-algo-trading-tool/', 'POSITIVE_SCORE': 8, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.7777776913580343, 'SUBJECTIVITY_SCORE': 0.025787965542154827, 'AVG_SENTENCE_LENGTH': 349.0, 'PERCENTAGE_COMPLEX_WORDS': 39.82808022922636, 'FOG_INDEX': 155.53123209169055, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 349.0, 'COMPLEX_WORD_COUNT': 139, 'WORD_COUNT': 349, 'SYLLABLE_PER_WORD': 2.2120343839541547, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.951289398280802}
# {'URL_ID': 'bctech2066', 'URL': 'https://insights.blackcoffer.com/ai-agent-development-and-deployment-in-jina-ai/', 'POSITIVE_SCORE': 11, 'NEGATIVE_SCORE': 6, 'POLARITY_SCORE': 0.2941176297577865, 'SUBJECTIVITY_SCORE': 0.06746031719261779, 'AVG_SENTENCE_LENGTH': 252.0, 'PERCENTAGE_COMPLEX_WORDS': 40.07936507936508, 'FOG_INDEX': 116.83174603174604, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 252.0, 'COMPLEX_WORD_COUNT': 101, 'WORD_COUNT': 252, 'SYLLABLE_PER_WORD': 2.3452380952380953, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.2103174603174605}
# {'URL_ID': 'bctech2067', 'URL': 'https://insights.blackcoffer.com/golden-record-a-knowledge-graph-database-approach-to-unfold-discovery-using-neo4j/', 'POSITIVE_SCORE': 13, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.6249999609375024, 'SUBJECTIVITY_SCORE': 0.04984423660484662, 'AVG_SENTENCE_LENGTH': 321.0, 'PERCENTAGE_COMPLEX_WORDS': 38.940809968847354, 'FOG_INDEX': 143.97632398753896, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 321.0, 'COMPLEX_WORD_COUNT': 125, 'WORD_COUNT': 321, 'SYLLABLE_PER_WORD': 2.3146417445482865, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.071651090342679}
# {'URL_ID': 'bctech2068', 'URL': 'https://insights.blackcoffer.com/advanced-ai-for-trading-automation/', 'POSITIVE_SCORE': 13, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.7333332844444478, 'SUBJECTIVITY_SCORE': 0.04518072275547975, 'AVG_SENTENCE_LENGTH': 332.0, 'PERCENTAGE_COMPLEX_WORDS': 40.06024096385542, 'FOG_INDEX': 148.8240963855422, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 332.0, 'COMPLEX_WORD_COUNT': 133, 'WORD_COUNT': 332, 'SYLLABLE_PER_WORD': 2.3373493975903616, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.969879518072289}
# {'URL_ID': 'bctech2069', 'URL': 'https://insights.blackcoffer.com/create-a-knowledge-graph-to-provide-real-time-analytics-recommendations-and-a-single-source-of-truth/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.33333329629630043, 'SUBJECTIVITY_SCORE': 0.039130434612476374, 'AVG_SENTENCE_LENGTH': 230.0, 'PERCENTAGE_COMPLEX_WORDS': 43.04347826086957, 'FOG_INDEX': 109.21739130434783, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 230.0, 'COMPLEX_WORD_COUNT': 99, 'WORD_COUNT': 230, 'SYLLABLE_PER_WORD': 2.3521739130434782, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.260869565217392}
# {'URL_ID': 'bctech2070', 'URL': 'https://insights.blackcoffer.com/advanced-ai-for-thermal-person-detection/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.031088082740476256, 'AVG_SENTENCE_LENGTH': 193.0, 'PERCENTAGE_COMPLEX_WORDS': 39.37823834196891, 'FOG_INDEX': 92.95129533678757, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 193.0, 'COMPLEX_WORD_COUNT': 76, 'WORD_COUNT': 193, 'SYLLABLE_PER_WORD': 2.321243523316062, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.227979274611399}
# {'URL_ID': 'bctech2071', 'URL': 'https://insights.blackcoffer.com/advanced-ai-for-road-cam-threat-detection/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.4999999375000079, 'SUBJECTIVITY_SCORE': 0.03940886680094154, 'AVG_SENTENCE_LENGTH': 203.0, 'PERCENTAGE_COMPLEX_WORDS': 41.87192118226601, 'FOG_INDEX': 97.94876847290641, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 203.0, 'COMPLEX_WORD_COUNT': 85, 'WORD_COUNT': 203, 'SYLLABLE_PER_WORD': 2.3596059113300494, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.295566502463054}
# {'URL_ID': 'bctech2072', 'URL': 'https://insights.blackcoffer.com/advanced-ai-for-pedestrian-crossing-safety/', 'POSITIVE_SCORE': 8, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.599999940000006, 'SUBJECTIVITY_SCORE': 0.04807692284578403, 'AVG_SENTENCE_LENGTH': 208.0, 'PERCENTAGE_COMPLEX_WORDS': 41.82692307692308, 'FOG_INDEX': 99.93076923076924, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 208.0, 'COMPLEX_WORD_COUNT': 87, 'WORD_COUNT': 208, 'SYLLABLE_PER_WORD': 2.360576923076923, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.360576923076923}
# {'URL_ID': 'bctech2073', 'URL': 'https://insights.blackcoffer.com/handgun-detection-using-yolo/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.034825870473503134, 'AVG_SENTENCE_LENGTH': 201.0, 'PERCENTAGE_COMPLEX_WORDS': 43.28358208955223, 'FOG_INDEX': 97.7134328358209, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 201.0, 'COMPLEX_WORD_COUNT': 87, 'WORD_COUNT': 201, 'SYLLABLE_PER_WORD': 2.388059701492537, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.343283582089552}
# {'URL_ID': 'bctech2074', 'URL': 'https://insights.blackcoffer.com/using-graph-technology-to-create-single-customer-view/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 5, 'POLARITY_SCORE': 0.16666665277777895, 'SUBJECTIVITY_SCORE': 0.05128205106289722, 'AVG_SENTENCE_LENGTH': 234.0, 'PERCENTAGE_COMPLEX_WORDS': 41.88034188034188, 'FOG_INDEX': 110.35213675213674, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 234.0, 'COMPLEX_WORD_COUNT': 98, 'WORD_COUNT': 234, 'SYLLABLE_PER_WORD': 2.3803418803418803, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.311965811965812}
# {'URL_ID': 'bctech2075', 'URL': 'https://insights.blackcoffer.com/car-detection-in-satellite-images/', 'POSITIVE_SCORE': 14, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999999285714337, 'SUBJECTIVITY_SCORE': 0.046666666511111114, 'AVG_SENTENCE_LENGTH': 300.0, 'PERCENTAGE_COMPLEX_WORDS': 38.666666666666664, 'FOG_INDEX': 135.46666666666667, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 300.0, 'COMPLEX_WORD_COUNT': 116, 'WORD_COUNT': 300, 'SYLLABLE_PER_WORD': 2.32, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.026666666666666}
# {'URL_ID': 'bctech2076', 'URL': 'https://insights.blackcoffer.com/building-a-physics-informed-neural-network-for-circuit-evaluation/', 'POSITIVE_SCORE': 11, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.5714285306122479, 'SUBJECTIVITY_SCORE': 0.04320987640984606, 'AVG_SENTENCE_LENGTH': 324.0, 'PERCENTAGE_COMPLEX_WORDS': 41.66666666666667, 'FOG_INDEX': 146.26666666666668, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 324.0, 'COMPLEX_WORD_COUNT': 135, 'WORD_COUNT': 324, 'SYLLABLE_PER_WORD': 2.330246913580247, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.37037037037037}
# {'URL_ID': 'bctech2077', 'URL': 'https://insights.blackcoffer.com/connecting-mongodb-database-to-power-bi-dashboard-dashboard-automation/', 'POSITIVE_SCORE': 8, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.4545454132231443, 'SUBJECTIVITY_SCORE': 0.03160919531146783, 'AVG_SENTENCE_LENGTH': 348.0, 'PERCENTAGE_COMPLEX_WORDS': 38.2183908045977, 'FOG_INDEX': 154.4873563218391, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 348.0, 'COMPLEX_WORD_COUNT': 133, 'WORD_COUNT': 348, 'SYLLABLE_PER_WORD': 2.2758620689655173, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.818965517241379}
# {'URL_ID': 'bctech2078', 'URL': 'https://insights.blackcoffer.com/data-transformation/', 'POSITIVE_SCORE': 17, 'NEGATIVE_SCORE': 12, 'POLARITY_SCORE': 0.17241378715814526, 'SUBJECTIVITY_SCORE': 0.07591623016775856, 'AVG_SENTENCE_LENGTH': 382.0, 'PERCENTAGE_COMPLEX_WORDS': 37.95811518324607, 'FOG_INDEX': 167.98324607329846, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 382.0, 'COMPLEX_WORD_COUNT': 145, 'WORD_COUNT': 382, 'SYLLABLE_PER_WORD': 2.225130890052356, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.7539267015706805}
# {'URL_ID': 'bctech2079', 'URL': 'https://insights.blackcoffer.com/e-commerce-store-analysis-purchase-behavior-ad-spend-conversion-traffic-etc/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.8181817438016598, 'SUBJECTIVITY_SCORE': 0.03273809514066043, 'AVG_SENTENCE_LENGTH': 336.0, 'PERCENTAGE_COMPLEX_WORDS': 40.17857142857143, 'FOG_INDEX': 150.4714285714286, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 336.0, 'COMPLEX_WORD_COUNT': 135, 'WORD_COUNT': 336, 'SYLLABLE_PER_WORD': 2.324404761904762, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.0476190476190474}
# {'URL_ID': 'bctech2080', 'URL': 'https://insights.blackcoffer.com/kpi-dashboard-for-accountants/', 'POSITIVE_SCORE': 12, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999999166666736, 'SUBJECTIVITY_SCORE': 0.038709677294484914, 'AVG_SENTENCE_LENGTH': 310.0, 'PERCENTAGE_COMPLEX_WORDS': 36.774193548387096, 'FOG_INDEX': 138.70967741935485, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 310.0, 'COMPLEX_WORD_COUNT': 114, 'WORD_COUNT': 310, 'SYLLABLE_PER_WORD': 2.235483870967742, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.109677419354838}
# {'URL_ID': 'bctech2081', 'URL': 'https://insights.blackcoffer.com/return-on-advertising-spend-dashboard-marketing-automation-and-analytics-using-etl-and-dashboard/', 'POSITIVE_SCORE': 27, 'NEGATIVE_SCORE': 4, 'POLARITY_SCORE': 0.7419354599375658, 'SUBJECTIVITY_SCORE': 0.05438596481686673, 'AVG_SENTENCE_LENGTH': 570.0, 'PERCENTAGE_COMPLEX_WORDS': 44.73684210526316, 'FOG_INDEX': 245.89473684210526, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 570.0, 'COMPLEX_WORD_COUNT': 255, 'WORD_COUNT': 570, 'SYLLABLE_PER_WORD': 2.354385964912281, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.2403508771929825}
# {'URL_ID': 'bctech2082', 'URL': 'https://insights.blackcoffer.com/ranking-customer-behaviours-for-business-strategy/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.4999999375000079, 'SUBJECTIVITY_SCORE': 0.030651340878730494, 'AVG_SENTENCE_LENGTH': 261.0, 'PERCENTAGE_COMPLEX_WORDS': 35.63218390804598, 'FOG_INDEX': 118.6528735632184, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 261.0, 'COMPLEX_WORD_COUNT': 93, 'WORD_COUNT': 261, 'SYLLABLE_PER_WORD': 2.264367816091954, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.0}
# {'URL_ID': 'bctech2083', 'URL': 'https://insights.blackcoffer.com/algorithmic-trading-for-multiple-commodities-markets-like-forex-metals-energy-etc/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.021943573598922968, 'AVG_SENTENCE_LENGTH': 319.0, 'PERCENTAGE_COMPLEX_WORDS': 40.75235109717868, 'FOG_INDEX': 143.9009404388715, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 319.0, 'COMPLEX_WORD_COUNT': 130, 'WORD_COUNT': 319, 'SYLLABLE_PER_WORD': 2.413793103448276, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.235109717868339}
# {'URL_ID': 'bctech2084', 'URL': 'https://insights.blackcoffer.com/trading-bot-for-forex/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.599999880000024, 'SUBJECTIVITY_SCORE': 0.02717391289579395, 'AVG_SENTENCE_LENGTH': 184.0, 'PERCENTAGE_COMPLEX_WORDS': 38.58695652173913, 'FOG_INDEX': 89.03478260869565, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 184.0, 'COMPLEX_WORD_COUNT': 71, 'WORD_COUNT': 184, 'SYLLABLE_PER_WORD': 2.3043478260869565, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.119565217391305}
# {'URL_ID': 'bctech2085', 'URL': 'https://insights.blackcoffer.com/python-model-for-the-analysis-of-sector-specific-stock-etfs-for-investment-purposes%ef%bf%bc/', 'POSITIVE_SCORE': 9, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.636363578512402, 'SUBJECTIVITY_SCORE': 0.037542661987909, 'AVG_SENTENCE_LENGTH': 293.0, 'PERCENTAGE_COMPLEX_WORDS': 37.20136518771331, 'FOG_INDEX': 132.08054607508532, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 293.0, 'COMPLEX_WORD_COUNT': 109, 'WORD_COUNT': 293, 'SYLLABLE_PER_WORD': 2.2866894197952217, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.088737201365188}
# {'URL_ID': 'bctech2086', 'URL': 'https://insights.blackcoffer.com/medical-classification/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.020689655101070153, 'AVG_SENTENCE_LENGTH': 290.0, 'PERCENTAGE_COMPLEX_WORDS': 37.58620689655172, 'FOG_INDEX': 131.0344827586207, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 290.0, 'COMPLEX_WORD_COUNT': 109, 'WORD_COUNT': 290, 'SYLLABLE_PER_WORD': 2.2758620689655173, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.024137931034483}
# {'URL_ID': 'bctech2087', 'URL': 'https://insights.blackcoffer.com/design-develop-bert-question-answering-model-explanations-with-visualization/', 'POSITIVE_SCORE': 3, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999996666667778, 'SUBJECTIVITY_SCORE': 0.01470588228085352, 'AVG_SENTENCE_LENGTH': 204.0, 'PERCENTAGE_COMPLEX_WORDS': 41.17647058823529, 'FOG_INDEX': 98.07058823529412, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 204.0, 'COMPLEX_WORD_COUNT': 84, 'WORD_COUNT': 204, 'SYLLABLE_PER_WORD': 2.3676470588235294, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.416666666666667}
# {'URL_ID': 'bctech2088', 'URL': 'https://insights.blackcoffer.com/design-and-develop-solution-to-anomaly-detection-classification-problems/', 'POSITIVE_SCORE': 3, 'NEGATIVE_SCORE': 7, 'POLARITY_SCORE': -0.39999996000000404, 'SUBJECTIVITY_SCORE': 0.04149377576143662, 'AVG_SENTENCE_LENGTH': 241.0, 'PERCENTAGE_COMPLEX_WORDS': 42.738589211618255, 'FOG_INDEX': 113.4954356846473, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 241.0, 'COMPLEX_WORD_COUNT': 103, 'WORD_COUNT': 241, 'SYLLABLE_PER_WORD': 2.3900414937759336, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.161825726141079}
# {'URL_ID': 'bctech2089', 'URL': 'https://insights.blackcoffer.com/an-etl-solution-for-currency-data-to-google-big-query/', 'POSITIVE_SCORE': 3, 'NEGATIVE_SCORE': 5, 'POLARITY_SCORE': -0.24999996875000394, 'SUBJECTIVITY_SCORE': 0.028880866321729724, 'AVG_SENTENCE_LENGTH': 277.0, 'PERCENTAGE_COMPLEX_WORDS': 33.2129963898917, 'FOG_INDEX': 124.0851985559567, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 277.0, 'COMPLEX_WORD_COUNT': 92, 'WORD_COUNT': 277, 'SYLLABLE_PER_WORD': 2.187725631768953, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.725631768953068}
# {'URL_ID': 'bctech2090', 'URL': 'https://insights.blackcoffer.com/etl-and-mlops-infrastructure-for-blockchain-analytics/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.013201320088444489, 'AVG_SENTENCE_LENGTH': 303.0, 'PERCENTAGE_COMPLEX_WORDS': 38.613861386138616, 'FOG_INDEX': 136.64554455445545, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 303.0, 'COMPLEX_WORD_COUNT': 117, 'WORD_COUNT': 303, 'SYLLABLE_PER_WORD': 2.201320132013201, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.003300330033003}
# {'URL_ID': 'bctech2091', 'URL': 'https://insights.blackcoffer.com/an-agent-based-model-of-a-virtual-power-plant-vpp/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.022471909986112867, 'AVG_SENTENCE_LENGTH': 178.0, 'PERCENTAGE_COMPLEX_WORDS': 38.764044943820224, 'FOG_INDEX': 86.7056179775281, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 178.0, 'COMPLEX_WORD_COUNT': 69, 'WORD_COUNT': 178, 'SYLLABLE_PER_WORD': 2.3258426966292136, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.213483146067416}
# {'URL_ID': 'bctech2092', 'URL': 'https://insights.blackcoffer.com/transform-api-into-sdk-library-and-widget/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999990000001, 'SUBJECTIVITY_SCORE': 0.042194092648970075, 'AVG_SENTENCE_LENGTH': 237.0, 'PERCENTAGE_COMPLEX_WORDS': 38.39662447257383, 'FOG_INDEX': 110.15864978902954, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 237.0, 'COMPLEX_WORD_COUNT': 91, 'WORD_COUNT': 237, 'SYLLABLE_PER_WORD': 2.2447257383966246, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.042194092827004}
# {'URL_ID': 'bctech2093', 'URL': 'https://insights.blackcoffer.com/integration-of-a-product-to-a-cloud-based-crm-platform/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 6, 'POLARITY_SCORE': 0.07692307100591762, 'SUBJECTIVITY_SCORE': 0.045774647726145604, 'AVG_SENTENCE_LENGTH': 284.0, 'PERCENTAGE_COMPLEX_WORDS': 38.732394366197184, 'FOG_INDEX': 129.09295774647887, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 284.0, 'COMPLEX_WORD_COUNT': 110, 'WORD_COUNT': 284, 'SYLLABLE_PER_WORD': 2.257042253521127, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.130281690140845}
# {'URL_ID': 'bctech2094', 'URL': 'https://insights.blackcoffer.com/a-web-based-dashboard-for-the-filtered-data-retrieval-of-land-records/', 'POSITIVE_SCORE': 12, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.5999999600000027, 'SUBJECTIVITY_SCORE': 0.04731861183811163, 'AVG_SENTENCE_LENGTH': 317.0, 'PERCENTAGE_COMPLEX_WORDS': 35.33123028391167, 'FOG_INDEX': 140.93249211356468, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 317.0, 'COMPLEX_WORD_COUNT': 112, 'WORD_COUNT': 317, 'SYLLABLE_PER_WORD': 2.2397476340694005, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.022082018927445}
# {'URL_ID': 'bctech2095', 'URL': 'https://insights.blackcoffer.com/integration-of-video-conferencing-data-to-the-existing-web-app/', 'POSITIVE_SCORE': 3, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999996666667778, 'SUBJECTIVITY_SCORE': 0.01153846149408284, 'AVG_SENTENCE_LENGTH': 260.0, 'PERCENTAGE_COMPLEX_WORDS': 34.61538461538461, 'FOG_INDEX': 117.84615384615387, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 260.0, 'COMPLEX_WORD_COUNT': 90, 'WORD_COUNT': 260, 'SYLLABLE_PER_WORD': 2.226923076923077, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.926923076923077}
# {'URL_ID': 'bctech2096', 'URL': 'https://insights.blackcoffer.com/design-develop-an-app-in-retool-which-shows-the-progress-of-the-added-video/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.026178010334146542, 'AVG_SENTENCE_LENGTH': 191.0, 'PERCENTAGE_COMPLEX_WORDS': 39.79057591623037, 'FOG_INDEX': 92.31623036649215, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 191.0, 'COMPLEX_WORD_COUNT': 76, 'WORD_COUNT': 191, 'SYLLABLE_PER_WORD': 2.319371727748691, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.057591623036649}
# ...
# {'URL_ID': 'bctech2129', 'URL': 'https://insights.blackcoffer.com/react-native-apps-in-the-development-portfolio/', 'POSITIVE_SCORE': 3, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999996666667778, 'SUBJECTIVITY_SCORE': 0.019354838584807493, 'AVG_SENTENCE_LENGTH': 155.0, 'PERCENTAGE_COMPLEX_WORDS': 41.935483870967744, 'FOG_INDEX': 78.7741935483871, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 155.0, 'COMPLEX_WORD_COUNT': 65, 'WORD_COUNT': 155, 'SYLLABLE_PER_WORD': 2.232258064516129, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.212903225806452}
# {'URL_ID': 'bctech2130', 'URL': 'https://insights.blackcoffer.com/a-leading-firm-website-seo-optimization/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.02551020395147855, 'AVG_SENTENCE_LENGTH': 196.0, 'PERCENTAGE_COMPLEX_WORDS': 43.87755102040816, 'FOG_INDEX': 95.95102040816327, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 196.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 196, 'SYLLABLE_PER_WORD': 2.3214285714285716, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.183673469387755}
# {'URL_ID': 'bctech2131', 'URL': 'https://insights.blackcoffer.com/a-leading-hospitality-firm-in-the-usa-website-seo-optimization/', 'POSITIVE_SCORE': 7, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998571428775, 'SUBJECTIVITY_SCORE': 0.035175879220221716, 'AVG_SENTENCE_LENGTH': 199.0, 'PERCENTAGE_COMPLEX_WORDS': 42.211055276381906, 'FOG_INDEX': 96.48442211055277, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 199.0, 'COMPLEX_WORD_COUNT': 84, 'WORD_COUNT': 199, 'SYLLABLE_PER_WORD': 2.306532663316583, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.165829145728643}
# {'URL_ID': 'bctech2132', 'URL': 'https://insights.blackcoffer.com/a-leading-firm-in-the-usa-website-seo-optimization/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.4285713673469475, 'SUBJECTIVITY_SCORE': 0.03804347805411153, 'AVG_SENTENCE_LENGTH': 184.0, 'PERCENTAGE_COMPLEX_WORDS': 39.130434782608695, 'FOG_INDEX': 89.25217391304348, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 184.0, 'COMPLEX_WORD_COUNT': 72, 'WORD_COUNT': 184, 'SYLLABLE_PER_WORD': 2.217391304347826, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.016304347826087}
# {'URL_ID': 'bctech2133', 'URL': 'https://insights.blackcoffer.com/a-leading-musical-instrumental-website-seo-optimization/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 3, 'POLARITY_SCORE': 0.24999996875000394, 'SUBJECTIVITY_SCORE': 0.04255319126301494, 'AVG_SENTENCE_LENGTH': 188.0, 'PERCENTAGE_COMPLEX_WORDS': 44.680851063829785, 'FOG_INDEX': 93.07234042553192, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 188.0, 'COMPLEX_WORD_COUNT': 84, 'WORD_COUNT': 188, 'SYLLABLE_PER_WORD': 2.3404255319148937, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.170212765957447}
# {'URL_ID': 'bctech2134', 'URL': 'https://insights.blackcoffer.com/a-leading-firm-in-the-usa-seo-and-website-optimization/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.02747252732157952, 'AVG_SENTENCE_LENGTH': 182.0, 'PERCENTAGE_COMPLEX_WORDS': 43.40659340659341, 'FOG_INDEX': 90.16263736263737, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 182.0, 'COMPLEX_WORD_COUNT': 79, 'WORD_COUNT': 182, 'SYLLABLE_PER_WORD': 2.318681318681319, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.230769230769231}
# {'URL_ID': 'bctech2135', 'URL': 'https://insights.blackcoffer.com/immigration-datawarehouse-ai-based-recommendations/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999990000001, 'SUBJECTIVITY_SCORE': 0.03597122289218985, 'AVG_SENTENCE_LENGTH': 278.0, 'PERCENTAGE_COMPLEX_WORDS': 40.647482014388494, 'FOG_INDEX': 127.45899280575541, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 278.0, 'COMPLEX_WORD_COUNT': 113, 'WORD_COUNT': 278, 'SYLLABLE_PER_WORD': 2.338129496402878, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.079136690647482}
# {'URL_ID': 'bctech2136', 'URL': 'https://insights.blackcoffer.com/lipsync-automation-for-celebrities-and-influencers/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.018604651076257438, 'AVG_SENTENCE_LENGTH': 215.0, 'PERCENTAGE_COMPLEX_WORDS': 37.2093023255814, 'FOG_INDEX': 100.88372093023257, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 215.0, 'COMPLEX_WORD_COUNT': 80, 'WORD_COUNT': 215, 'SYLLABLE_PER_WORD': 2.302325581395349, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.046511627906977}
# {'URL_ID': 'bctech2137', 'URL': 'https://insights.blackcoffer.com/key-audit-matters-predictive-modeling/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 7, 'POLARITY_SCORE': -0.2727272479338866, 'SUBJECTIVITY_SCORE': 0.03013698621880278, 'AVG_SENTENCE_LENGTH': 365.0, 'PERCENTAGE_COMPLEX_WORDS': 39.178082191780824, 'FOG_INDEX': 161.67123287671234, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 365.0, 'COMPLEX_WORD_COUNT': 143, 'WORD_COUNT': 365, 'SYLLABLE_PER_WORD': 2.317808219178082, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.846575342465753}
# {'URL_ID': 'bctech2138', 'URL': 'https://insights.blackcoffer.com/splitting-of-songs-into-its-vocals-and-instrumental/', 'POSITIVE_SCORE': 11, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.6923076390532585, 'SUBJECTIVITY_SCORE': 0.05098039195693964, 'AVG_SENTENCE_LENGTH': 255.0, 'PERCENTAGE_COMPLEX_WORDS': 35.68627450980392, 'FOG_INDEX': 116.27450980392157, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 255.0, 'COMPLEX_WORD_COUNT': 91, 'WORD_COUNT': 255, 'SYLLABLE_PER_WORD': 2.2666666666666666, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.968627450980392}
# {'URL_ID': 'bctech2139', 'URL': 'https://insights.blackcoffer.com/ai-and-ml-technologies-to-evaluate-learning-assessments/', 'POSITIVE_SCORE': 13, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.7333332844444478, 'SUBJECTIVITY_SCORE': 0.04792332253059641, 'AVG_SENTENCE_LENGTH': 313.0, 'PERCENTAGE_COMPLEX_WORDS': 42.17252396166134, 'FOG_INDEX': 142.06900958466454, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 313.0, 'COMPLEX_WORD_COUNT': 132, 'WORD_COUNT': 313, 'SYLLABLE_PER_WORD': 2.4792332268370605, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.354632587859425}
# {'URL_ID': 'bctech2140', 'URL': 'https://insights.blackcoffer.com/datawarehouse-and-recommendations-engine-for-airbnb/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.6666666111111158, 'SUBJECTIVITY_SCORE': 0.04332129948259459, 'AVG_SENTENCE_LENGTH': 277.0, 'PERCENTAGE_COMPLEX_WORDS': 38.628158844765345, 'FOG_INDEX': 126.25126353790614, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 277.0, 'COMPLEX_WORD_COUNT': 107, 'WORD_COUNT': 277, 'SYLLABLE_PER_WORD': 2.3285198555956677, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.1046931407942235}
# {'URL_ID': 'bctech2141', 'URL': 'https://insights.blackcoffer.com/real-estate-data-warehouse/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999998333333611, 'SUBJECTIVITY_SCORE': 0.020905923272104797, 'AVG_SENTENCE_LENGTH': 287.0, 'PERCENTAGE_COMPLEX_WORDS': 38.67595818815331, 'FOG_INDEX': 130.2703832752613, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 287.0, 'COMPLEX_WORD_COUNT': 111, 'WORD_COUNT': 287, 'SYLLABLE_PER_WORD': 2.3310104529616726, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.031358885017422}
# {'URL_ID': 'bctech2142', 'URL': 'https://insights.blackcoffer.com/traction-dashboards-of-marketing-campaigns-and-posts/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.6666665555555741, 'SUBJECTIVITY_SCORE': 0.020905923272104797, 'AVG_SENTENCE_LENGTH': 287.0, 'PERCENTAGE_COMPLEX_WORDS': 34.84320557491289, 'FOG_INDEX': 128.73728222996516, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 287.0, 'COMPLEX_WORD_COUNT': 100, 'WORD_COUNT': 287, 'SYLLABLE_PER_WORD': 2.2369337979094075, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.979094076655052}
# {'URL_ID': 'bctech2143', 'URL': 'https://insights.blackcoffer.com/google-local-service-ads-lsa-data-warehouse/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.02222222212345679, 'AVG_SENTENCE_LENGTH': 225.0, 'PERCENTAGE_COMPLEX_WORDS': 40.44444444444444, 'FOG_INDEX': 106.17777777777779, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 225.0, 'COMPLEX_WORD_COUNT': 91, 'WORD_COUNT': 225, 'SYLLABLE_PER_WORD': 2.2933333333333334, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.946666666666666}
# {'URL_ID': 'bctech2144', 'URL': 'https://insights.blackcoffer.com/google-local-service-ads-missed-calls-and-messages-automation-tool/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 1, 'POLARITY_SCORE': 0.6666665555555741, 'SUBJECTIVITY_SCORE': 0.026431717945234724, 'AVG_SENTENCE_LENGTH': 227.0, 'PERCENTAGE_COMPLEX_WORDS': 37.88546255506608, 'FOG_INDEX': 105.95418502202642, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 227.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 227, 'SYLLABLE_PER_WORD': 2.2202643171806167, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.889867841409692}
# {'URL_ID': 'bctech2145', 'URL': 'https://insights.blackcoffer.com/marketing-ads-leads-call-status-data-tool-to-bigquery/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.023148148040980795, 'AVG_SENTENCE_LENGTH': 216.0, 'PERCENTAGE_COMPLEX_WORDS': 40.74074074074074, 'FOG_INDEX': 102.69629629629631, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 216.0, 'COMPLEX_WORD_COUNT': 88, 'WORD_COUNT': 216, 'SYLLABLE_PER_WORD': 2.314814814814815, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.060185185185185}
# {'URL_ID': 'bctech2146', 'URL': 'https://insights.blackcoffer.com/marketing-analytics-to-automate-leads-call-status-and-reporting/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.02252252242106972, 'AVG_SENTENCE_LENGTH': 222.0, 'PERCENTAGE_COMPLEX_WORDS': 38.73873873873874, 'FOG_INDEX': 104.2954954954955, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 222.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 222, 'SYLLABLE_PER_WORD': 2.2837837837837838, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.0675675675675675}
# {'URL_ID': 'bctech2147', 'URL': 'https://insights.blackcoffer.com/callrail-analytics-leads-report-alert/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.02304147454819597, 'AVG_SENTENCE_LENGTH': 217.0, 'PERCENTAGE_COMPLEX_WORDS': 39.63133640552996, 'FOG_INDEX': 102.652534562212, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 217.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 217, 'SYLLABLE_PER_WORD': 2.3179723502304146, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.082949308755761}
# {'URL_ID': 'bctech2148', 'URL': 'https://insights.blackcoffer.com/marketing-automation-tool-to-notify-lead-details-to-clients-over-email-and-phone/', 'POSITIVE_SCORE': 4, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999997500000625, 'SUBJECTIVITY_SCORE': 0.019801980099990197, 'AVG_SENTENCE_LENGTH': 202.0, 'PERCENTAGE_COMPLEX_WORDS': 40.099009900990104, 'FOG_INDEX': 96.83960396039605, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 202.0, 'COMPLEX_WORD_COUNT': 81, 'WORD_COUNT': 202, 'SYLLABLE_PER_WORD': 2.282178217821782, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.069306930693069}
# {'URL_ID': 'bctech2149', 'URL': 'https://insights.blackcoffer.com/data-etl-local-service-ads-leads-to-bigquery/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.024630541750588465, 'AVG_SENTENCE_LENGTH': 203.0, 'PERCENTAGE_COMPLEX_WORDS': 41.37931034482759, 'FOG_INDEX': 97.75172413793103, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 203.0, 'COMPLEX_WORD_COUNT': 84, 'WORD_COUNT': 203, 'SYLLABLE_PER_WORD': 2.310344827586207, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.068965517241379}
# {'URL_ID': 'bctech2150', 'URL': 'https://insights.blackcoffer.com/marbles-stimulation-using-python/', 'POSITIVE_SCORE': 6, 'NEGATIVE_SCORE': 2, 'POLARITY_SCORE': 0.4999999375000079, 'SUBJECTIVITY_SCORE': 0.032388663836483145, 'AVG_SENTENCE_LENGTH': 247.0, 'PERCENTAGE_COMPLEX_WORDS': 34.81781376518219, 'FOG_INDEX': 112.72712550607287, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 247.0, 'COMPLEX_WORD_COUNT': 86, 'WORD_COUNT': 247, 'SYLLABLE_PER_WORD': 2.0890688259109313, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.582995951417004}
# {'URL_ID': 'bctech2151', 'URL': 'https://insights.blackcoffer.com/stocktwits-data-structurization/', 'POSITIVE_SCORE': 12, 'NEGATIVE_SCORE': 6, 'POLARITY_SCORE': 0.3333333148148158, 'SUBJECTIVITY_SCORE': 0.027820710930725332, 'AVG_SENTENCE_LENGTH': 647.0, 'PERCENTAGE_COMPLEX_WORDS': 31.839258114374037, 'FOG_INDEX': 271.53570324574963, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 647.0, 'COMPLEX_WORD_COUNT': 206, 'WORD_COUNT': 647, 'SYLLABLE_PER_WORD': 2.2117465224111283, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.727975270479135}
# {'URL_ID': 'bctech2152', 'URL': 'https://insights.blackcoffer.com/sentimental-analysis-on-shareholder-letter-of-companies/', 'POSITIVE_SCORE': 11, 'NEGATIVE_SCORE': 7, 'POLARITY_SCORE': 0.2222222098765439, 'SUBJECTIVITY_SCORE': 0.04186046501892915, 'AVG_SENTENCE_LENGTH': 430.0, 'PERCENTAGE_COMPLEX_WORDS': 46.04651162790698, 'FOG_INDEX': 190.4186046511628, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 430.0, 'COMPLEX_WORD_COUNT': 198, 'WORD_COUNT': 430, 'SYLLABLE_PER_WORD': 2.4, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.988372093023256}
# {'URL_ID': 'bctech2153', 'URL': 'https://insights.blackcoffer.com/population-and-community-survey-of-america/', 'POSITIVE_SCORE': 10, 'NEGATIVE_SCORE': 8, 'POLARITY_SCORE': 0.11111110493827195, 'SUBJECTIVITY_SCORE': 0.027272727231404958, 'AVG_SENTENCE_LENGTH': 660.0, 'PERCENTAGE_COMPLEX_WORDS': 38.18181818181819, 'FOG_INDEX': 279.2727272727273, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 660.0, 'COMPLEX_WORD_COUNT': 252, 'WORD_COUNT': 660, 'SYLLABLE_PER_WORD': 2.2015151515151516, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.631818181818182}
# {'URL_ID': 'bctech2154', 'URL': 'https://insights.blackcoffer.com/google-lsa-api-data-automation-and-dashboarding/', 'POSITIVE_SCORE': 14, 'NEGATIVE_SCORE': 9, 'POLARITY_SCORE': 0.21739129489603065, 'SUBJECTIVITY_SCORE': 0.024757804063769855, 'AVG_SENTENCE_LENGTH': 929.0, 'PERCENTAGE_COMPLEX_WORDS': 34.33799784714747, 'FOG_INDEX': 385.335199138859, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 929.0, 'COMPLEX_WORD_COUNT': 319, 'WORD_COUNT': 929, 'SYLLABLE_PER_WORD': 2.1743810548977396, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.5844994617868675}
# {'URL_ID': 'bctech2155', 'URL': 'https://insights.blackcoffer.com/healthcare-data-analysis/', 'POSITIVE_SCORE': 9, 'NEGATIVE_SCORE': 6, 'POLARITY_SCORE': 0.19999998666666757, 'SUBJECTIVITY_SCORE': 0.06302520981922181, 'AVG_SENTENCE_LENGTH': 238.0, 'PERCENTAGE_COMPLEX_WORDS': 36.97478991596639, 'FOG_INDEX': 109.98991596638655, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 238.0, 'COMPLEX_WORD_COUNT': 88, 'WORD_COUNT': 238, 'SYLLABLE_PER_WORD': 2.2394957983193278, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 6.9033613445378155}
# {'URL_ID': 'bctech2156', 'URL': 'https://insights.blackcoffer.com/budget-sales-kpi-dashboard-using-power-bi/', 'POSITIVE_SCORE': 3, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.9999996666667778, 'SUBJECTIVITY_SCORE': 0.020270270133308985, 'AVG_SENTENCE_LENGTH': 148.0, 'PERCENTAGE_COMPLEX_WORDS': 43.91891891891892, 'FOG_INDEX': 76.76756756756757, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 148.0, 'COMPLEX_WORD_COUNT': 65, 'WORD_COUNT': 148, 'SYLLABLE_PER_WORD': 2.445945945945946, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.6824324324324325}
# {'URL_ID': 'bctech2157', 'URL': 'https://insights.blackcoffer.com/amazon-buy-bot-an-automation-ai-tool-to-auto-checkouts/', 'POSITIVE_SCORE': 5, 'NEGATIVE_SCORE': 0, 'POLARITY_SCORE': 0.99999980000004, 'SUBJECTIVITY_SCORE': 0.025252525124987248, 'AVG_SENTENCE_LENGTH': 198.0, 'PERCENTAGE_COMPLEX_WORDS': 39.39393939393939, 'FOG_INDEX': 94.95757575757575, 'AVG_NUMBER_OF_WORDS_PER_SENTENCE': 198.0, 'COMPLEX_WORD_COUNT': 78, 'WORD_COUNT': 198, 'SYLLABLE_PER_WORD': 2.297979797979798, 'PERSONAL_PRONOUNS': 0, 'AVG_WORD_LENGTH': 7.070707070707071}

# %%
output_df
# Out:
#          URL_ID                                                URL  \
# 0    bctech2011  https://insights.blackcoffer.com/ml-and-ai-bas...
# 1    bctech2012  https://insights.blackcoffer.com/streamlined-i...
# 2    bctech2013  https://insights.blackcoffer.com/efficient-dat...
# 3    bctech2014  https://insights.blackcoffer.com/effective-man...
# 4    bctech2015  https://insights.blackcoffer.com/streamlined-t...
# ..          ...                                                ...
# 142  bctech2153  https://insights.blackcoffer.com/population-an...
# 143  bctech2154  https://insights.blackcoffer.com/google-lsa-ap...
# 144  bctech2155  https://insights.blackcoffer.com/healthcare-da...
# 145  bctech2156  https://insights.blackcoffer.com/budget-sales-...
# 146  bctech2157  https://insights.blackcoffer.com/amazon-buy-bo...
#
#     POSITIVE_SCORE NEGATIVE_SCORE  POLARITY_SCORE  SUBJECTIVITY_SCORE  \
# 0               34              8        0.619048            0.071550
# 1                4              0        1.000000            0.021390
# 2                4              0        1.000000            0.021622
# 3                4              0        1.000000            0.021390
# 4                4              0        1.000000            0.021277
# ..             ...            ...             ...                 ...
# 142             10              8        0.111111            0.027273
# 143             14              9        0.217391            0.024758
# 144              9              6        0.200000            0.063025
# 145              3              0        1.000000            0.020270
# 146              5              0        1.000000            0.025253
#
#      AVG_SENTENCE_LENGTH  PERCENTAGE_COMPLEX_WORDS   FOG_INDEX  \
# 0                  587.0                 51.618399  255.447359
# 1                  187.0                 42.780749   91.912299
# 2                  185.0                 44.324324   91.729730
# 3                  187.0                 43.850267   92.340107
# 4                  188.0                 44.148936   92.859574
# ..                   ...                       ...         ...
# 142                660.0                 38.181818  279.272727
# 143                929.0                 34.337998  385.335199
# 144                238.0                 36.974790  109.989916
# 145                148.0                 43.918919   76.767568
# 146                198.0                 39.393939   94.957576
#
#      AVG_NUMBER_OF_WORDS_PER_SENTENCE COMPLEX_WORD_COUNT WORD_COUNT  \
# 0                               587.0                303        587
# 1                               187.0                 80        187
# 2                               185.0                 82        185
# 3                               187.0                 82        187
# 4                               188.0                 83        188
# ..                                ...                ...        ...
# 142                             660.0                252        660
# 143                             929.0                319        929
# 144                             238.0                 88        238
# 145                             148.0                 65        148
# 146                             198.0                 78        198
#
#      SYLLABLE_PER_WORD PERSONAL_PRONOUNS  AVG_WORD_LENGTH
# 0             2.592845                 0         7.630324
# 1             2.347594                 0         7.491979
# 2             2.367568                 0         7.524324
# 3             2.390374                 0         7.518717
# 4             2.372340                 0         7.537234
# ..                 ...               ...              ...
# 142           2.201515                 0         6.631818
# 143           2.174381                 0         6.584499
# 144           2.239496                 0         6.903361
# 145           2.445946                 0         7.682432
# 146           2.297980                 0         7.070707
#
# [147 rows x 15 columns]

# %%
# Save to Excel
output_df.to_excel('Output Data Structure.xlsx', index=False)
print("DataFrame saved successfully.")
# Out:
# DataFrame saved successfully.
